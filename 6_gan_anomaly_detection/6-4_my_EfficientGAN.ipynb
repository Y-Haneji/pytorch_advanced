# %%
# パッケージのimport
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# Setup seeds
torch.manual_seed(1234)
torch.cuda.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
class Generator(nn.Module):

    def __init__(self, z_dim=20):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Linear(z_dim, 1024),
            nn.BatchNorm1d(1024),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.Linear(1024, 7*7*128),
            nn.BatchNorm1d(7*7*128),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(in_channels=128, out_channels=64,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(in_channels=64, out_channels=1,
                               kernel_size=4, stride=2, padding=1),
            nn.Tanh())
        # 注意：白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)

        # 転置畳み込み層に入れるためにテンソルの形を整形
        out = out.view(z.shape[0], 128, 7, 7)
        out = self.layer3(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20)
G.train()

# 入力する乱数
# バッチノーマライゼーションがあるのでミニバッチ数は2以上
input_z = torch.randn(2, 20)

# 偽画像を出力
fake_images = G(input_z)  # torch.Size([2, 1, 28, 28])
img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %%
class Discriminator(nn.Module):

    def __init__(self, z_dim=20):
        super(Discriminator, self).__init__()

        # 画像側の入力処理
        self.x_layer1 = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 注意：白黒画像なので入力チャネルは1つだけ

        self.x_layer2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=4,
                      stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True))

        # 乱数側の入力処理
        self.z_layer1 = nn.Linear(z_dim, 512)

        # 最後の判定
        self.last1 = nn.Sequential(
            nn.Linear(3648, 1024),
            nn.LeakyReLU(0.1, inplace=True))

        self.last2 = nn.Linear(1024, 1)

    def forward(self, x, z):
        x_out = self.x_layer1(x)
        x_out = self.x_layer2(x_out)

        z = z.view(z.shape[0], -1)
        z_out = self.z_layer1(z)

        x_out = x_out.view(-1, 64*7*7)
        out = torch.cat([x_out, z_out], dim=1)
        out = self.last1(out)

        feature = out
        feature = feature.view(feature.size()[0], -1)

        out = self.last2(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20)

# 偽画像を生成
input_z = torch.randn(2, 20)
fake_images = G(input_z)

# 偽画像をDに入力
d_out, _ = D(fake_images, input_z)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out))
# Out:
# tensor([[0.4763],
#         [0.4597]], grad_fn=<SigmoidBackward0>)

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim=20):
        super(Encoder, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.layer3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1, inplace=True)
        )

        self.last = nn.Linear(128*7*7, z_dim)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)

        out = out.view(-1, 128*7*7)
        out = self.last(out)

        return out

# %%
# 動作確認
E = Encoder(z_dim=20)

# 入力する画像データ
x = fake_images  # fake_imagesは上のGで作成したもの

# 画像からzをEncode
z = E(x)

print(z.shape)
print(z)
# Out:
# torch.Size([2, 20])
# tensor([[-0.6751, -0.0820, -0.4010,  0.9686,  0.6298,  0.7464,  0.4240, -0.3878,
#          -0.4385,  0.1586, -0.0271, -0.2916, -0.4379,  0.1131, -0.2364, -0.2330,
#          -0.5561, -0.1676, -0.0151,  0.6888],
#         [ 0.1798,  0.3254, -0.8815, -0.2940,  0.8880, -0.2520,  0.0432,  0.0735,
#           0.4732, -0.2041,  0.2466, -0.7394, -0.6007,  0.5939,  0.1680, -0.0871,
#          -0.5606,  0.0651, -0.2073,  0.4276]], grad_fn=<AddmmBackward0>)

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed

# %%
# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imges = next(batch_iterator)  # 1番目の要素を取り出す
print(imges.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 28, 28])

# %%
def train_model(G, D, E, dataloader, num_epochs):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print("使用デバイス：", device)

    # 最適化手法の設定
    lr_ge = 0.0001
    lr_d = 0.0001/4
    beta1, beta2 = 0.5, 0.999
    g_optimizer = torch.optim.Adam(G.parameters(), lr_ge, [beta1, beta2])
    e_optimizer = torch.optim.Adam(E.parameters(), lr_ge, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), lr_d, [beta1, beta2])

    criterion = nn.BCEWithLogitsLoss(reduction='mean')

    # パラメータをハードコーディング
    z_dim = 20
    mini_batch_size = 64

    # ネットワークをGPUへ
    G.to(device)
    E.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    E.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    iteration = 1
    logs = []

    for epoch in range(num_epochs):
        t_epoch_start = time.time()
        epoch_g_loss = 0.0
        epoch_e_loss = 0.0
        epoch_d_loss = 0.0

        print('-------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------')
        print('（train）')

        for imges in dataloader:
            if imges.size()[0] == 1:
                continue

            mini_batch_size = imges.size()[0]
            label_real = torch.full((mini_batch_size,), 1, dtype=torch.float).to(device)
            label_fake = torch.full((mini_batch_size,), 0, dtype=torch.float).to(device)

            imges = imges.to(device)

            # Discriminatorの学習
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images, input_z)

            d_loss_real = criterion(d_out_real.view(-1), label_real)
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            d_optimizer.zero_grad()
            d_loss.backward()
            d_optimizer.step()

            # Generatorの学習
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            fake_images = G(input_z)
            d_out_fake, _  = D(fake_images, input_z)

            g_loss = criterion(d_out_fake.view(-1), label_real)

            g_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # Encoderの学習
            z_out_real = E(imges)
            d_out_real, _ = D(imges, z_out_real)

            e_loss = criterion(d_out_real.view(-1), label_fake)

            e_optimizer.zero_grad()
            e_loss.backward()
            e_optimizer.step()

            # 記録
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            epoch_e_loss += e_loss.item()
            iteration += 1

        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f} ||Epoch_E_Loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size, epoch_e_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    print("総イテレーション回数:", iteration)

    return G, D, E

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        m.bias.data.fill_(0)


G.apply(weights_init)
E.apply(weights_init)
D.apply(weights_init)

print('ネットワークの初期化完了')
# Out:
# ネットワークの初期化完了

# %%
num_epochs = 1500
G_update, D_update, E_update = train_model(
    G, D, E, dataloader=train_dataloader, num_epochs=num_epochs
)
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 0/1500
# -------------
# （train）
# -------------
# epoch 0 || Epoch_D_Loss:0.1513 ||Epoch_G_Loss:0.0759 ||Epoch_E_Loss:0.0770
# timer:  1.5265 sec.
# -------------
# Epoch 1/1500
# -------------
# （train）
# -------------
# epoch 1 || Epoch_D_Loss:0.1470 ||Epoch_G_Loss:0.0782 ||Epoch_E_Loss:0.0792
# timer:  0.1426 sec.
# -------------
# Epoch 2/1500
# -------------
# （train）
# -------------
# epoch 2 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.0800 ||Epoch_E_Loss:0.0823
# timer:  0.1367 sec.
# -------------
# Epoch 3/1500
# -------------
# （train）
# -------------
# epoch 3 || Epoch_D_Loss:0.1370 ||Epoch_G_Loss:0.0818 ||Epoch_E_Loss:0.0865
# timer:  0.1344 sec.
# -------------
# Epoch 4/1500
# -------------
# （train）
# -------------
# epoch 4 || Epoch_D_Loss:0.1333 ||Epoch_G_Loss:0.0836 ||Epoch_E_Loss:0.0897
# timer:  0.1357 sec.
# -------------
# Epoch 5/1500
# -------------
# （train）
# -------------
# epoch 5 || Epoch_D_Loss:0.1306 ||Epoch_G_Loss:0.0846 ||Epoch_E_Loss:0.0922
# timer:  0.1338 sec.
# -------------
# Epoch 6/1500
# -------------
# （train）
# -------------
# epoch 6 || Epoch_D_Loss:0.1256 ||Epoch_G_Loss:0.0858 ||Epoch_E_Loss:0.0977
# timer:  0.1352 sec.
# -------------
# Epoch 7/1500
# -------------
# （train）
# -------------
# epoch 7 || Epoch_D_Loss:0.1203 ||Epoch_G_Loss:0.0876 ||Epoch_E_Loss:0.1048
# timer:  0.1335 sec.
# -------------
# Epoch 8/1500
# -------------
# （train）
# -------------
# epoch 8 || Epoch_D_Loss:0.1177 ||Epoch_G_Loss:0.0892 ||Epoch_E_Loss:0.1065
# timer:  0.1349 sec.
# -------------
# Epoch 9/1500
# -------------
# （train）
# -------------
# epoch 9 || Epoch_D_Loss:0.1173 ||Epoch_G_Loss:0.0899 ||Epoch_E_Loss:0.1059
# timer:  0.1338 sec.
# -------------
# Epoch 10/1500
# -------------
# （train）
# -------------
# epoch 10 || Epoch_D_Loss:0.1128 ||Epoch_G_Loss:0.0924 ||Epoch_E_Loss:0.1118
# timer:  0.1359 sec.
# -------------
# Epoch 11/1500
# -------------
# （train）
# -------------
# epoch 11 || Epoch_D_Loss:0.1060 ||Epoch_G_Loss:0.0931 ||Epoch_E_Loss:0.1234
# timer:  0.1336 sec.
# -------------
# Epoch 12/1500
# -------------
# （train）
# -------------
# epoch 12 || Epoch_D_Loss:0.1032 ||Epoch_G_Loss:0.0968 ||Epoch_E_Loss:0.1245
# timer:  0.1347 sec.
# -------------
# Epoch 13/1500
# -------------
# （train）
# -------------
# epoch 13 || Epoch_D_Loss:0.1019 ||Epoch_G_Loss:0.1012 ||Epoch_E_Loss:0.1229
# timer:  0.1337 sec.
# -------------
# Epoch 14/1500
# -------------
# （train）
# -------------
# epoch 14 || Epoch_D_Loss:0.0950 ||Epoch_G_Loss:0.1031 ||Epoch_E_Loss:0.1329
# timer:  0.1357 sec.
# -------------
# Epoch 15/1500
# -------------
# （train）
# -------------
# epoch 15 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1068 ||Epoch_E_Loss:0.1388
# timer:  0.1337 sec.
# -------------
# Epoch 16/1500
# -------------
# （train）
# -------------
# epoch 16 || Epoch_D_Loss:0.0881 ||Epoch_G_Loss:0.1111 ||Epoch_E_Loss:0.1394
# timer:  0.1361 sec.
# -------------
# Epoch 17/1500
# -------------
# （train）
# -------------
# epoch 17 || Epoch_D_Loss:0.0808 ||Epoch_G_Loss:0.1145 ||Epoch_E_Loss:0.1548
# timer:  0.1361 sec.
# -------------
# Epoch 18/1500
# -------------
# （train）
# -------------
# epoch 18 || Epoch_D_Loss:0.0734 ||Epoch_G_Loss:0.1207 ||Epoch_E_Loss:0.1686
# timer:  0.1388 sec.
# -------------
# Epoch 19/1500
# -------------
# （train）
# -------------
# epoch 19 || Epoch_D_Loss:0.0691 ||Epoch_G_Loss:0.1303 ||Epoch_E_Loss:0.1703
# timer:  0.1341 sec.
# -------------
# Epoch 20/1500
# -------------
# （train）
# -------------
# epoch 20 || Epoch_D_Loss:0.0673 ||Epoch_G_Loss:0.1375 ||Epoch_E_Loss:0.1692
# timer:  0.1356 sec.
# -------------
# Epoch 21/1500
# -------------
# （train）
# -------------
# epoch 21 || Epoch_D_Loss:0.0613 ||Epoch_G_Loss:0.1428 ||Epoch_E_Loss:0.1816
# timer:  0.1336 sec.
# -------------
# Epoch 22/1500
# -------------
# （train）
# -------------
# epoch 22 || Epoch_D_Loss:0.0539 ||Epoch_G_Loss:0.1517 ||Epoch_E_Loss:0.2015
# timer:  0.1353 sec.
# -------------
# Epoch 23/1500
# -------------
# （train）
# -------------
# epoch 23 || Epoch_D_Loss:0.0517 ||Epoch_G_Loss:0.1577 ||Epoch_E_Loss:0.2008
# timer:  0.1335 sec.
# -------------
# Epoch 24/1500
# -------------
# （train）
# -------------
# epoch 24 || Epoch_D_Loss:0.0475 ||Epoch_G_Loss:0.1676 ||Epoch_E_Loss:0.2115
# timer:  0.1354 sec.
# -------------
# Epoch 25/1500
# -------------
# （train）
# -------------
# epoch 25 || Epoch_D_Loss:0.0420 ||Epoch_G_Loss:0.1769 ||Epoch_E_Loss:0.2280
# timer:  0.1338 sec.
# -------------
# Epoch 26/1500
# -------------
# （train）
# -------------
# epoch 26 || Epoch_D_Loss:0.0388 ||Epoch_G_Loss:0.1844 ||Epoch_E_Loss:0.2328
# timer:  0.1352 sec.
# -------------
# Epoch 27/1500
# -------------
# （train）
# -------------
# epoch 27 || Epoch_D_Loss:0.0380 ||Epoch_G_Loss:0.1925 ||Epoch_E_Loss:0.2300
# timer:  0.1336 sec.
# -------------
# Epoch 28/1500
# -------------
# （train）
# -------------
# epoch 28 || Epoch_D_Loss:0.0338 ||Epoch_G_Loss:0.2032 ||Epoch_E_Loss:0.2477
# timer:  0.1351 sec.
# -------------
# Epoch 29/1500
# -------------
# （train）
# -------------
# epoch 29 || Epoch_D_Loss:0.0304 ||Epoch_G_Loss:0.2103 ||Epoch_E_Loss:0.2630
# timer:  0.1336 sec.
# -------------
# Epoch 30/1500
# -------------
# （train）
# -------------
# epoch 30 || Epoch_D_Loss:0.0279 ||Epoch_G_Loss:0.2165 ||Epoch_E_Loss:0.2774
# timer:  0.1357 sec.
# -------------
# Epoch 31/1500
# -------------
# （train）
# -------------
# epoch 31 || Epoch_D_Loss:0.0259 ||Epoch_G_Loss:0.2239 ||Epoch_E_Loss:0.2919
# timer:  0.1353 sec.
# -------------
# Epoch 32/1500
# -------------
# （train）
# -------------
# epoch 32 || Epoch_D_Loss:0.0250 ||Epoch_G_Loss:0.2275 ||Epoch_E_Loss:0.2943
# timer:  0.1356 sec.
# -------------
# Epoch 33/1500
# -------------
# （train）
# -------------
# epoch 33 || Epoch_D_Loss:0.0261 ||Epoch_G_Loss:0.2366 ||Epoch_E_Loss:0.2857
# timer:  0.1340 sec.
# -------------
# Epoch 34/1500
# -------------
# （train）
# -------------
# epoch 34 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.2474 ||Epoch_E_Loss:0.2799
# timer:  0.1493 sec.
# -------------
# Epoch 35/1500
# -------------
# （train）
# -------------
# epoch 35 || Epoch_D_Loss:0.0254 ||Epoch_G_Loss:0.2532 ||Epoch_E_Loss:0.2762
# timer:  0.1354 sec.
# -------------
# Epoch 36/1500
# -------------
# （train）
# -------------
# epoch 36 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.2660 ||Epoch_E_Loss:0.3113
# timer:  0.1359 sec.
# -------------
# Epoch 37/1500
# -------------
# （train）
# -------------
# epoch 37 || Epoch_D_Loss:0.0166 ||Epoch_G_Loss:0.2724 ||Epoch_E_Loss:0.3400
# timer:  0.1345 sec.
# -------------
# Epoch 38/1500
# -------------
# （train）
# -------------
# epoch 38 || Epoch_D_Loss:0.0150 ||Epoch_G_Loss:0.2846 ||Epoch_E_Loss:0.3563
# timer:  0.1360 sec.
# -------------
# Epoch 39/1500
# -------------
# （train）
# -------------
# epoch 39 || Epoch_D_Loss:0.0141 ||Epoch_G_Loss:0.2843 ||Epoch_E_Loss:0.3597
# timer:  0.1345 sec.
# -------------
# Epoch 40/1500
# -------------
# （train）
# -------------
# epoch 40 || Epoch_D_Loss:0.0144 ||Epoch_G_Loss:0.2929 ||Epoch_E_Loss:0.3512
# timer:  0.1364 sec.
# -------------
# Epoch 41/1500
# -------------
# （train）
# -------------
# epoch 41 || Epoch_D_Loss:0.0155 ||Epoch_G_Loss:0.2987 ||Epoch_E_Loss:0.3318
# timer:  0.1345 sec.
# -------------
# Epoch 42/1500
# -------------
# （train）
# -------------
# epoch 42 || Epoch_D_Loss:0.0171 ||Epoch_G_Loss:0.3017 ||Epoch_E_Loss:0.3219
# timer:  0.1358 sec.
# -------------
# Epoch 43/1500
# -------------
# （train）
# -------------
# epoch 43 || Epoch_D_Loss:0.0155 ||Epoch_G_Loss:0.3061 ||Epoch_E_Loss:0.3315
# timer:  0.1342 sec.
# -------------
# Epoch 44/1500
# -------------
# （train）
# -------------
# epoch 44 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.3151 ||Epoch_E_Loss:0.3284
# timer:  0.1359 sec.
# -------------
# Epoch 45/1500
# -------------
# （train）
# -------------
# epoch 45 || Epoch_D_Loss:0.0134 ||Epoch_G_Loss:0.3204 ||Epoch_E_Loss:0.3456
# timer:  0.1341 sec.
# -------------
# Epoch 46/1500
# -------------
# （train）
# -------------
# epoch 46 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.3284 ||Epoch_E_Loss:0.3669
# timer:  0.1405 sec.
# -------------
# Epoch 47/1500
# -------------
# （train）
# -------------
# epoch 47 || Epoch_D_Loss:0.0107 ||Epoch_G_Loss:0.3414 ||Epoch_E_Loss:0.3747
# timer:  0.1340 sec.
# -------------
# Epoch 48/1500
# -------------
# （train）
# -------------
# epoch 48 || Epoch_D_Loss:0.0102 ||Epoch_G_Loss:0.3451 ||Epoch_E_Loss:0.3720
# timer:  0.1360 sec.
# -------------
# Epoch 49/1500
# -------------
# （train）
# -------------
# epoch 49 || Epoch_D_Loss:0.0110 ||Epoch_G_Loss:0.3531 ||Epoch_E_Loss:0.3541
# timer:  0.1336 sec.
# -------------
# Epoch 50/1500
# -------------
# （train）
# -------------
# epoch 50 || Epoch_D_Loss:0.0121 ||Epoch_G_Loss:0.3585 ||Epoch_E_Loss:0.3362
# timer:  0.1395 sec.
# -------------
# Epoch 51/1500
# -------------
# （train）
# -------------
# epoch 51 || Epoch_D_Loss:0.0118 ||Epoch_G_Loss:0.3569 ||Epoch_E_Loss:0.3434
# timer:  0.1381 sec.
# -------------
# Epoch 52/1500
# -------------
# （train）
# -------------
# epoch 52 || Epoch_D_Loss:0.0111 ||Epoch_G_Loss:0.3626 ||Epoch_E_Loss:0.3578
# timer:  0.1356 sec.
# -------------
# Epoch 53/1500
# -------------
# （train）
# -------------
# epoch 53 || Epoch_D_Loss:0.0095 ||Epoch_G_Loss:0.3698 ||Epoch_E_Loss:0.3778
# timer:  0.1340 sec.
# -------------
# Epoch 54/1500
# -------------
# （train）
# -------------
# epoch 54 || Epoch_D_Loss:0.0086 ||Epoch_G_Loss:0.3742 ||Epoch_E_Loss:0.3924
# timer:  0.1356 sec.
# -------------
# Epoch 55/1500
# -------------
# （train）
# -------------
# epoch 55 || Epoch_D_Loss:0.0078 ||Epoch_G_Loss:0.3800 ||Epoch_E_Loss:0.4033
# timer:  0.1340 sec.
# -------------
# Epoch 56/1500
# -------------
# （train）
# -------------
# epoch 56 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.3839 ||Epoch_E_Loss:0.4085
# timer:  0.1359 sec.
# -------------
# Epoch 57/1500
# -------------
# （train）
# -------------
# epoch 57 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.3901 ||Epoch_E_Loss:0.4040
# timer:  0.1337 sec.
# -------------
# Epoch 58/1500
# -------------
# （train）
# -------------
# epoch 58 || Epoch_D_Loss:0.0079 ||Epoch_G_Loss:0.3919 ||Epoch_E_Loss:0.3901
# timer:  0.1353 sec.
# -------------
# Epoch 59/1500
# -------------
# （train）
# -------------
# epoch 59 || Epoch_D_Loss:0.0071 ||Epoch_G_Loss:0.3980 ||Epoch_E_Loss:0.4099
# timer:  0.1343 sec.
# -------------
# Epoch 60/1500
# -------------
# （train）
# -------------
# epoch 60 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4017 ||Epoch_E_Loss:0.4262
# timer:  0.1358 sec.
# -------------
# Epoch 61/1500
# -------------
# （train）
# -------------
# epoch 61 || Epoch_D_Loss:0.0058 ||Epoch_G_Loss:0.4169 ||Epoch_E_Loss:0.4373
# timer:  0.1359 sec.
# -------------
# Epoch 62/1500
# -------------
# （train）
# -------------
# epoch 62 || Epoch_D_Loss:0.0053 ||Epoch_G_Loss:0.4222 ||Epoch_E_Loss:0.4530
# timer:  0.1373 sec.
# -------------
# Epoch 63/1500
# -------------
# （train）
# -------------
# epoch 63 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.4275 ||Epoch_E_Loss:0.4629
# timer:  0.1348 sec.
# -------------
# Epoch 64/1500
# -------------
# （train）
# -------------
# epoch 64 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.4263 ||Epoch_E_Loss:0.4560
# timer:  0.1359 sec.
# -------------
# Epoch 65/1500
# -------------
# （train）
# -------------
# epoch 65 || Epoch_D_Loss:0.0057 ||Epoch_G_Loss:0.4268 ||Epoch_E_Loss:0.4379
# timer:  0.1338 sec.
# -------------
# Epoch 66/1500
# -------------
# （train）
# -------------
# epoch 66 || Epoch_D_Loss:0.0055 ||Epoch_G_Loss:0.4276 ||Epoch_E_Loss:0.4470
# timer:  0.1364 sec.
# -------------
# Epoch 67/1500
# -------------
# （train）
# -------------
# epoch 67 || Epoch_D_Loss:0.0046 ||Epoch_G_Loss:0.4401 ||Epoch_E_Loss:0.4714
# timer:  0.1379 sec.
# -------------
# Epoch 68/1500
# -------------
# （train）
# -------------
# epoch 68 || Epoch_D_Loss:0.0040 ||Epoch_G_Loss:0.4497 ||Epoch_E_Loss:0.4888
# timer:  0.1361 sec.
# -------------
# Epoch 69/1500
# -------------
# （train）
# -------------
# epoch 69 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:0.4517 ||Epoch_E_Loss:0.4808
# timer:  0.1342 sec.
# -------------
# Epoch 70/1500
# -------------
# （train）
# -------------
# epoch 70 || Epoch_D_Loss:0.0047 ||Epoch_G_Loss:0.4489 ||Epoch_E_Loss:0.4639
# timer:  0.1359 sec.
# -------------
# Epoch 71/1500
# -------------
# （train）
# -------------
# epoch 71 || Epoch_D_Loss:0.0054 ||Epoch_G_Loss:0.4426 ||Epoch_E_Loss:0.4527
# timer:  0.1344 sec.
# -------------
# Epoch 72/1500
# -------------
# （train）
# -------------
# epoch 72 || Epoch_D_Loss:0.0064 ||Epoch_G_Loss:0.4408 ||Epoch_E_Loss:0.4285
# timer:  0.1358 sec.
# -------------
# Epoch 73/1500
# -------------
# （train）
# -------------
# epoch 73 || Epoch_D_Loss:0.0076 ||Epoch_G_Loss:0.4254 ||Epoch_E_Loss:0.4241
# timer:  0.1334 sec.
# -------------
# Epoch 74/1500
# -------------
# （train）
# -------------
# epoch 74 || Epoch_D_Loss:0.0059 ||Epoch_G_Loss:0.4235 ||Epoch_E_Loss:0.4417
# timer:  0.1357 sec.
# -------------
# Epoch 75/1500
# -------------
# （train）
# -------------
# epoch 75 || Epoch_D_Loss:0.0066 ||Epoch_G_Loss:0.4255 ||Epoch_E_Loss:0.4329
# timer:  0.1339 sec.
# -------------
# Epoch 76/1500
# -------------
# （train）
# -------------
# epoch 76 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.4218 ||Epoch_E_Loss:0.4368
# timer:  0.1367 sec.
# -------------
# Epoch 77/1500
# -------------
# （train）
# -------------
# epoch 77 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.4201 ||Epoch_E_Loss:0.4233
# timer:  0.1343 sec.
# -------------
# Epoch 78/1500
# -------------
# （train）
# -------------
# epoch 78 || Epoch_D_Loss:0.0081 ||Epoch_G_Loss:0.4209 ||Epoch_E_Loss:0.3981
# timer:  0.1359 sec.
# -------------
# Epoch 79/1500
# -------------
# （train）
# -------------
# epoch 79 || Epoch_D_Loss:0.0171 ||Epoch_G_Loss:0.3744 ||Epoch_E_Loss:0.4087
# timer:  0.1356 sec.
# -------------
# Epoch 80/1500
# -------------
# （train）
# -------------
# epoch 80 || Epoch_D_Loss:0.0153 ||Epoch_G_Loss:0.3474 ||Epoch_E_Loss:0.3674
# timer:  0.1359 sec.
# -------------
# Epoch 81/1500
# -------------
# （train）
# -------------
# epoch 81 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.3694 ||Epoch_E_Loss:0.3714
# timer:  0.1343 sec.
# -------------
# Epoch 82/1500
# -------------
# （train）
# -------------
# epoch 82 || Epoch_D_Loss:0.0242 ||Epoch_G_Loss:0.3512 ||Epoch_E_Loss:0.3465
# timer:  0.1363 sec.
# -------------
# Epoch 83/1500
# -------------
# （train）
# -------------
# epoch 83 || Epoch_D_Loss:0.0188 ||Epoch_G_Loss:0.3519 ||Epoch_E_Loss:0.3585
# timer:  0.1403 sec.
# -------------
# Epoch 84/1500
# -------------
# （train）
# -------------
# epoch 84 || Epoch_D_Loss:0.0244 ||Epoch_G_Loss:0.3079 ||Epoch_E_Loss:0.3555
# timer:  0.1374 sec.
# -------------
# Epoch 85/1500
# -------------
# （train）
# -------------
# epoch 85 || Epoch_D_Loss:0.0378 ||Epoch_G_Loss:0.3591 ||Epoch_E_Loss:0.3550
# timer:  0.1379 sec.
# -------------
# Epoch 86/1500
# -------------
# （train）
# -------------
# epoch 86 || Epoch_D_Loss:0.0199 ||Epoch_G_Loss:0.3339 ||Epoch_E_Loss:0.3361
# timer:  0.1375 sec.
# -------------
# Epoch 87/1500
# -------------
# （train）
# -------------
# epoch 87 || Epoch_D_Loss:0.0199 ||Epoch_G_Loss:0.3249 ||Epoch_E_Loss:0.3458
# timer:  0.1342 sec.
# -------------
# Epoch 88/1500
# -------------
# （train）
# -------------
# epoch 88 || Epoch_D_Loss:0.0324 ||Epoch_G_Loss:0.2799 ||Epoch_E_Loss:0.2994
# timer:  0.1368 sec.
# -------------
# Epoch 89/1500
# -------------
# （train）
# -------------
# epoch 89 || Epoch_D_Loss:0.0192 ||Epoch_G_Loss:0.3520 ||Epoch_E_Loss:0.3381
# timer:  0.1344 sec.
# -------------
# Epoch 90/1500
# -------------
# （train）
# -------------
# epoch 90 || Epoch_D_Loss:0.0157 ||Epoch_G_Loss:0.3573 ||Epoch_E_Loss:0.3619
# timer:  0.1367 sec.
# -------------
# Epoch 91/1500
# -------------
# （train）
# -------------
# epoch 91 || Epoch_D_Loss:0.0165 ||Epoch_G_Loss:0.3322 ||Epoch_E_Loss:0.3689
# timer:  0.1357 sec.
# -------------
# Epoch 92/1500
# -------------
# （train）
# -------------
# epoch 92 || Epoch_D_Loss:0.0334 ||Epoch_G_Loss:0.3075 ||Epoch_E_Loss:0.3323
# timer:  0.1365 sec.
# -------------
# Epoch 93/1500
# -------------
# （train）
# -------------
# epoch 93 || Epoch_D_Loss:0.0309 ||Epoch_G_Loss:0.2914 ||Epoch_E_Loss:0.3156
# timer:  0.1337 sec.
# -------------
# Epoch 94/1500
# -------------
# （train）
# -------------
# epoch 94 || Epoch_D_Loss:0.0300 ||Epoch_G_Loss:0.2883 ||Epoch_E_Loss:0.3187
# timer:  0.1356 sec.
# -------------
# Epoch 95/1500
# -------------
# （train）
# -------------
# epoch 95 || Epoch_D_Loss:0.0375 ||Epoch_G_Loss:0.2613 ||Epoch_E_Loss:0.3224
# timer:  0.1336 sec.
# -------------
# Epoch 96/1500
# -------------
# （train）
# -------------
# epoch 96 || Epoch_D_Loss:0.0450 ||Epoch_G_Loss:0.2998 ||Epoch_E_Loss:0.3026
# timer:  0.1358 sec.
# -------------
# Epoch 97/1500
# -------------
# （train）
# -------------
# epoch 97 || Epoch_D_Loss:0.0320 ||Epoch_G_Loss:0.2832 ||Epoch_E_Loss:0.3125
# timer:  0.1335 sec.
# -------------
# Epoch 98/1500
# -------------
# （train）
# -------------
# epoch 98 || Epoch_D_Loss:0.0268 ||Epoch_G_Loss:0.3039 ||Epoch_E_Loss:0.3254
# timer:  0.1351 sec.
# -------------
# Epoch 99/1500
# -------------
# （train）
# -------------
# epoch 99 || Epoch_D_Loss:0.0295 ||Epoch_G_Loss:0.3031 ||Epoch_E_Loss:0.3125
# timer:  0.1343 sec.
# -------------
# Epoch 100/1500
# -------------
# （train）
# -------------
# epoch 100 || Epoch_D_Loss:0.0501 ||Epoch_G_Loss:0.2733 ||Epoch_E_Loss:0.2971
# timer:  0.1402 sec.
# -------------
# Epoch 101/1500
# -------------
# （train）
# -------------
# epoch 101 || Epoch_D_Loss:0.0654 ||Epoch_G_Loss:0.2160 ||Epoch_E_Loss:0.2968
# timer:  0.1337 sec.
# -------------
# Epoch 102/1500
# -------------
# （train）
# -------------
# epoch 102 || Epoch_D_Loss:0.0569 ||Epoch_G_Loss:0.2757 ||Epoch_E_Loss:0.2914
# timer:  0.1360 sec.
# -------------
# Epoch 103/1500
# -------------
# （train）
# -------------
# epoch 103 || Epoch_D_Loss:0.0505 ||Epoch_G_Loss:0.2535 ||Epoch_E_Loss:0.2818
# timer:  0.1343 sec.
# -------------
# Epoch 104/1500
# -------------
# （train）
# -------------
# epoch 104 || Epoch_D_Loss:0.0445 ||Epoch_G_Loss:0.2601 ||Epoch_E_Loss:0.2902
# timer:  0.1363 sec.
# -------------
# Epoch 105/1500
# -------------
# （train）
# -------------
# epoch 105 || Epoch_D_Loss:0.0550 ||Epoch_G_Loss:0.2401 ||Epoch_E_Loss:0.2741
# timer:  0.1349 sec.
# -------------
# Epoch 106/1500
# -------------
# （train）
# -------------
# epoch 106 || Epoch_D_Loss:0.0598 ||Epoch_G_Loss:0.2443 ||Epoch_E_Loss:0.2706
# timer:  0.1371 sec.
# -------------
# Epoch 107/1500
# -------------
# （train）
# -------------
# epoch 107 || Epoch_D_Loss:0.0515 ||Epoch_G_Loss:0.2273 ||Epoch_E_Loss:0.2805
# timer:  0.1340 sec.
# -------------
# Epoch 108/1500
# -------------
# （train）
# -------------
# epoch 108 || Epoch_D_Loss:0.0625 ||Epoch_G_Loss:0.2338 ||Epoch_E_Loss:0.2427
# timer:  0.1362 sec.
# -------------
# Epoch 109/1500
# -------------
# （train）
# -------------
# epoch 109 || Epoch_D_Loss:0.0591 ||Epoch_G_Loss:0.2126 ||Epoch_E_Loss:0.2593
# timer:  0.1337 sec.
# -------------
# Epoch 110/1500
# -------------
# （train）
# -------------
# epoch 110 || Epoch_D_Loss:0.0500 ||Epoch_G_Loss:0.2314 ||Epoch_E_Loss:0.2625
# timer:  0.1359 sec.
# -------------
# Epoch 111/1500
# -------------
# （train）
# -------------
# epoch 111 || Epoch_D_Loss:0.0491 ||Epoch_G_Loss:0.2440 ||Epoch_E_Loss:0.2647
# timer:  0.1337 sec.
# -------------
# Epoch 112/1500
# -------------
# （train）
# -------------
# epoch 112 || Epoch_D_Loss:0.0647 ||Epoch_G_Loss:0.2174 ||Epoch_E_Loss:0.2665
# timer:  0.1352 sec.
# -------------
# Epoch 113/1500
# -------------
# （train）
# -------------
# epoch 113 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.2523 ||Epoch_E_Loss:0.2587
# timer:  0.1339 sec.
# -------------
# Epoch 114/1500
# -------------
# （train）
# -------------
# epoch 114 || Epoch_D_Loss:0.0444 ||Epoch_G_Loss:0.2691 ||Epoch_E_Loss:0.2814
# timer:  0.1359 sec.
# -------------
# Epoch 115/1500
# -------------
# （train）
# -------------
# epoch 115 || Epoch_D_Loss:0.0428 ||Epoch_G_Loss:0.2505 ||Epoch_E_Loss:0.2745
# timer:  0.1347 sec.
# -------------
# Epoch 116/1500
# -------------
# （train）
# -------------
# epoch 116 || Epoch_D_Loss:0.0671 ||Epoch_G_Loss:0.2023 ||Epoch_E_Loss:0.2296
# timer:  0.1374 sec.
# -------------
# Epoch 117/1500
# -------------
# （train）
# -------------
# epoch 117 || Epoch_D_Loss:0.1045 ||Epoch_G_Loss:0.1719 ||Epoch_E_Loss:0.1969
# timer:  0.1351 sec.
# -------------
# Epoch 118/1500
# -------------
# （train）
# -------------
# epoch 118 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.1927 ||Epoch_E_Loss:0.2193
# timer:  0.1361 sec.
# -------------
# Epoch 119/1500
# -------------
# （train）
# -------------
# epoch 119 || Epoch_D_Loss:0.0638 ||Epoch_G_Loss:0.2186 ||Epoch_E_Loss:0.2302
# timer:  0.1343 sec.
# -------------
# Epoch 120/1500
# -------------
# （train）
# -------------
# epoch 120 || Epoch_D_Loss:0.0591 ||Epoch_G_Loss:0.2186 ||Epoch_E_Loss:0.2419
# timer:  0.1360 sec.
# -------------
# Epoch 121/1500
# -------------
# （train）
# -------------
# epoch 121 || Epoch_D_Loss:0.0502 ||Epoch_G_Loss:0.2069 ||Epoch_E_Loss:0.2554
# timer:  0.1388 sec.
# -------------
# Epoch 122/1500
# -------------
# （train）
# -------------
# epoch 122 || Epoch_D_Loss:0.0554 ||Epoch_G_Loss:0.2308 ||Epoch_E_Loss:0.2406
# timer:  0.1362 sec.
# -------------
# Epoch 123/1500
# -------------
# （train）
# -------------
# epoch 123 || Epoch_D_Loss:0.0653 ||Epoch_G_Loss:0.2249 ||Epoch_E_Loss:0.2390
# timer:  0.1343 sec.
# -------------
# Epoch 124/1500
# -------------
# （train）
# -------------
# epoch 124 || Epoch_D_Loss:0.1011 ||Epoch_G_Loss:0.1667 ||Epoch_E_Loss:0.1900
# timer:  0.1349 sec.
# -------------
# Epoch 125/1500
# -------------
# （train）
# -------------
# epoch 125 || Epoch_D_Loss:0.1024 ||Epoch_G_Loss:0.1878 ||Epoch_E_Loss:0.1895
# timer:  0.1355 sec.
# -------------
# Epoch 126/1500
# -------------
# （train）
# -------------
# epoch 126 || Epoch_D_Loss:0.0772 ||Epoch_G_Loss:0.2298 ||Epoch_E_Loss:0.2482
# timer:  0.1355 sec.
# -------------
# Epoch 127/1500
# -------------
# （train）
# -------------
# epoch 127 || Epoch_D_Loss:0.0544 ||Epoch_G_Loss:0.2277 ||Epoch_E_Loss:0.2671
# timer:  0.1342 sec.
# -------------
# Epoch 128/1500
# -------------
# （train）
# -------------
# epoch 128 || Epoch_D_Loss:0.0486 ||Epoch_G_Loss:0.2389 ||Epoch_E_Loss:0.2574
# timer:  0.1354 sec.
# -------------
# Epoch 129/1500
# -------------
# （train）
# -------------
# epoch 129 || Epoch_D_Loss:0.0559 ||Epoch_G_Loss:0.2512 ||Epoch_E_Loss:0.2318
# timer:  0.1338 sec.
# -------------
# Epoch 130/1500
# -------------
# （train）
# -------------
# epoch 130 || Epoch_D_Loss:0.0697 ||Epoch_G_Loss:0.2125 ||Epoch_E_Loss:0.2166
# timer:  0.1353 sec.
# -------------
# Epoch 131/1500
# -------------
# （train）
# -------------
# epoch 131 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.1900 ||Epoch_E_Loss:0.1785
# timer:  0.1336 sec.
# -------------
# Epoch 132/1500
# -------------
# （train）
# -------------
# epoch 132 || Epoch_D_Loss:0.1134 ||Epoch_G_Loss:0.1554 ||Epoch_E_Loss:0.1910
# timer:  0.1381 sec.
# -------------
# Epoch 133/1500
# -------------
# （train）
# -------------
# epoch 133 || Epoch_D_Loss:0.1053 ||Epoch_G_Loss:0.1523 ||Epoch_E_Loss:0.1874
# timer:  0.1369 sec.
# -------------
# Epoch 134/1500
# -------------
# （train）
# -------------
# epoch 134 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1856 ||Epoch_E_Loss:0.2087
# timer:  0.1356 sec.
# -------------
# Epoch 135/1500
# -------------
# （train）
# -------------
# epoch 135 || Epoch_D_Loss:0.0728 ||Epoch_G_Loss:0.2127 ||Epoch_E_Loss:0.2070
# timer:  0.1351 sec.
# -------------
# Epoch 136/1500
# -------------
# （train）
# -------------
# epoch 136 || Epoch_D_Loss:0.0862 ||Epoch_G_Loss:0.1943 ||Epoch_E_Loss:0.1984
# timer:  0.1368 sec.
# -------------
# Epoch 137/1500
# -------------
# （train）
# -------------
# epoch 137 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.1714 ||Epoch_E_Loss:0.2002
# timer:  0.1340 sec.
# -------------
# Epoch 138/1500
# -------------
# （train）
# -------------
# epoch 138 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1693 ||Epoch_E_Loss:0.1848
# timer:  0.1355 sec.
# -------------
# Epoch 139/1500
# -------------
# （train）
# -------------
# epoch 139 || Epoch_D_Loss:0.0946 ||Epoch_G_Loss:0.1639 ||Epoch_E_Loss:0.1841
# timer:  0.1333 sec.
# -------------
# Epoch 140/1500
# -------------
# （train）
# -------------
# epoch 140 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.1868 ||Epoch_E_Loss:0.1916
# timer:  0.1354 sec.
# -------------
# Epoch 141/1500
# -------------
# （train）
# -------------
# epoch 141 || Epoch_D_Loss:0.0864 ||Epoch_G_Loss:0.1698 ||Epoch_E_Loss:0.2034
# timer:  0.1335 sec.
# -------------
# Epoch 142/1500
# -------------
# （train）
# -------------
# epoch 142 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.1737 ||Epoch_E_Loss:0.1929
# timer:  0.1357 sec.
# -------------
# Epoch 143/1500
# -------------
# （train）
# -------------
# epoch 143 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2031 ||Epoch_E_Loss:0.1959
# timer:  0.1335 sec.
# -------------
# Epoch 144/1500
# -------------
# （train）
# -------------
# epoch 144 || Epoch_D_Loss:0.0823 ||Epoch_G_Loss:0.1728 ||Epoch_E_Loss:0.2042
# timer:  0.1355 sec.
# -------------
# Epoch 145/1500
# -------------
# （train）
# -------------
# epoch 145 || Epoch_D_Loss:0.0848 ||Epoch_G_Loss:0.2053 ||Epoch_E_Loss:0.1810
# timer:  0.1340 sec.
# -------------
# Epoch 146/1500
# -------------
# （train）
# -------------
# epoch 146 || Epoch_D_Loss:0.0834 ||Epoch_G_Loss:0.2112 ||Epoch_E_Loss:0.1870
# timer:  0.1358 sec.
# -------------
# Epoch 147/1500
# -------------
# （train）
# -------------
# epoch 147 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.2005 ||Epoch_E_Loss:0.2099
# timer:  0.1337 sec.
# -------------
# Epoch 148/1500
# -------------
# （train）
# -------------
# epoch 148 || Epoch_D_Loss:0.0696 ||Epoch_G_Loss:0.1939 ||Epoch_E_Loss:0.2040
# timer:  0.1354 sec.
# -------------
# Epoch 149/1500
# -------------
# （train）
# -------------
# epoch 149 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.2057 ||Epoch_E_Loss:0.1944
# timer:  0.1422 sec.
# -------------
# Epoch 150/1500
# -------------
# （train）
# -------------
# epoch 150 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.2175 ||Epoch_E_Loss:0.2039
# timer:  0.1357 sec.
# -------------
# Epoch 151/1500
# -------------
# （train）
# -------------
# epoch 151 || Epoch_D_Loss:0.0697 ||Epoch_G_Loss:0.1944 ||Epoch_E_Loss:0.2126
# timer:  0.1354 sec.
# -------------
# Epoch 152/1500
# -------------
# （train）
# -------------
# epoch 152 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1899 ||Epoch_E_Loss:0.2027
# timer:  0.1375 sec.
# -------------
# Epoch 153/1500
# -------------
# （train）
# -------------
# epoch 153 || Epoch_D_Loss:0.0825 ||Epoch_G_Loss:0.1890 ||Epoch_E_Loss:0.1910
# timer:  0.1353 sec.
# -------------
# Epoch 154/1500
# -------------
# （train）
# -------------
# epoch 154 || Epoch_D_Loss:0.0824 ||Epoch_G_Loss:0.1622 ||Epoch_E_Loss:0.1909
# timer:  0.1368 sec.
# -------------
# Epoch 155/1500
# -------------
# （train）
# -------------
# epoch 155 || Epoch_D_Loss:0.0874 ||Epoch_G_Loss:0.1797 ||Epoch_E_Loss:0.1805
# timer:  0.1349 sec.
# -------------
# Epoch 156/1500
# -------------
# （train）
# -------------
# epoch 156 || Epoch_D_Loss:0.0798 ||Epoch_G_Loss:0.1792 ||Epoch_E_Loss:0.1891
# timer:  0.1365 sec.
# -------------
# Epoch 157/1500
# -------------
# （train）
# -------------
# epoch 157 || Epoch_D_Loss:0.0727 ||Epoch_G_Loss:0.1944 ||Epoch_E_Loss:0.1992
# timer:  0.1359 sec.
# -------------
# Epoch 158/1500
# -------------
# （train）
# -------------
# epoch 158 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.1910 ||Epoch_E_Loss:0.1958
# timer:  0.1368 sec.
# -------------
# Epoch 159/1500
# -------------
# （train）
# -------------
# epoch 159 || Epoch_D_Loss:0.0800 ||Epoch_G_Loss:0.1866 ||Epoch_E_Loss:0.1955
# timer:  0.1370 sec.
# -------------
# Epoch 160/1500
# -------------
# （train）
# -------------
# epoch 160 || Epoch_D_Loss:0.0815 ||Epoch_G_Loss:0.1846 ||Epoch_E_Loss:0.1919
# timer:  0.1364 sec.
# -------------
# Epoch 161/1500
# -------------
# （train）
# -------------
# epoch 161 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1834 ||Epoch_E_Loss:0.1813
# timer:  0.1348 sec.
# -------------
# Epoch 162/1500
# -------------
# （train）
# -------------
# epoch 162 || Epoch_D_Loss:0.1030 ||Epoch_G_Loss:0.1491 ||Epoch_E_Loss:0.1791
# timer:  0.1381 sec.
# -------------
# Epoch 163/1500
# -------------
# （train）
# -------------
# epoch 163 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1495 ||Epoch_E_Loss:0.1644
# timer:  0.1354 sec.
# -------------
# Epoch 164/1500
# -------------
# （train）
# -------------
# epoch 164 || Epoch_D_Loss:0.1153 ||Epoch_G_Loss:0.1412 ||Epoch_E_Loss:0.1466
# timer:  0.1379 sec.
# -------------
# Epoch 165/1500
# -------------
# （train）
# -------------
# epoch 165 || Epoch_D_Loss:0.1105 ||Epoch_G_Loss:0.1373 ||Epoch_E_Loss:0.1509
# timer:  0.1371 sec.
# -------------
# Epoch 166/1500
# -------------
# （train）
# -------------
# epoch 166 || Epoch_D_Loss:0.1290 ||Epoch_G_Loss:0.1410 ||Epoch_E_Loss:0.1350
# timer:  0.1375 sec.
# -------------
# Epoch 167/1500
# -------------
# （train）
# -------------
# epoch 167 || Epoch_D_Loss:0.1145 ||Epoch_G_Loss:0.1414 ||Epoch_E_Loss:0.1585
# timer:  0.1349 sec.
# -------------
# Epoch 168/1500
# -------------
# （train）
# -------------
# epoch 168 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1467 ||Epoch_E_Loss:0.1521
# timer:  0.1361 sec.
# -------------
# Epoch 169/1500
# -------------
# （train）
# -------------
# epoch 169 || Epoch_D_Loss:0.1001 ||Epoch_G_Loss:0.1579 ||Epoch_E_Loss:0.1587
# timer:  0.1400 sec.
# -------------
# Epoch 170/1500
# -------------
# （train）
# -------------
# epoch 170 || Epoch_D_Loss:0.1038 ||Epoch_G_Loss:0.1566 ||Epoch_E_Loss:0.1550
# timer:  0.1375 sec.
# -------------
# Epoch 171/1500
# -------------
# （train）
# -------------
# epoch 171 || Epoch_D_Loss:0.0985 ||Epoch_G_Loss:0.1452 ||Epoch_E_Loss:0.1608
# timer:  0.1357 sec.
# -------------
# Epoch 172/1500
# -------------
# （train）
# -------------
# epoch 172 || Epoch_D_Loss:0.1044 ||Epoch_G_Loss:0.1660 ||Epoch_E_Loss:0.1533
# timer:  0.1373 sec.
# -------------
# Epoch 173/1500
# -------------
# （train）
# -------------
# epoch 173 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1523 ||Epoch_E_Loss:0.1605
# timer:  0.1368 sec.
# -------------
# Epoch 174/1500
# -------------
# （train）
# -------------
# epoch 174 || Epoch_D_Loss:0.0957 ||Epoch_G_Loss:0.1662 ||Epoch_E_Loss:0.1559
# timer:  0.1388 sec.
# -------------
# Epoch 175/1500
# -------------
# （train）
# -------------
# epoch 175 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1703 ||Epoch_E_Loss:0.1644
# timer:  0.1369 sec.
# -------------
# Epoch 176/1500
# -------------
# （train）
# -------------
# epoch 176 || Epoch_D_Loss:0.0945 ||Epoch_G_Loss:0.1591 ||Epoch_E_Loss:0.1654
# timer:  0.1370 sec.
# -------------
# Epoch 177/1500
# -------------
# （train）
# -------------
# epoch 177 || Epoch_D_Loss:0.0960 ||Epoch_G_Loss:0.1702 ||Epoch_E_Loss:0.1629
# timer:  0.1368 sec.
# -------------
# Epoch 178/1500
# -------------
# （train）
# -------------
# epoch 178 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.1755 ||Epoch_E_Loss:0.1634
# timer:  0.1377 sec.
# -------------
# Epoch 179/1500
# -------------
# （train）
# -------------
# epoch 179 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1617
# timer:  0.1378 sec.
# -------------
# Epoch 180/1500
# -------------
# （train）
# -------------
# epoch 180 || Epoch_D_Loss:0.0992 ||Epoch_G_Loss:0.1504 ||Epoch_E_Loss:0.1537
# timer:  0.1388 sec.
# -------------
# Epoch 181/1500
# -------------
# （train）
# -------------
# epoch 181 || Epoch_D_Loss:0.1064 ||Epoch_G_Loss:0.1490 ||Epoch_E_Loss:0.1504
# timer:  0.1392 sec.
# -------------
# Epoch 182/1500
# -------------
# （train）
# -------------
# epoch 182 || Epoch_D_Loss:0.1067 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1452
# timer:  0.1387 sec.
# -------------
# Epoch 183/1500
# -------------
# （train）
# -------------
# epoch 183 || Epoch_D_Loss:0.1245 ||Epoch_G_Loss:0.1457 ||Epoch_E_Loss:0.1482
# timer:  0.1357 sec.
# -------------
# Epoch 184/1500
# -------------
# （train）
# -------------
# epoch 184 || Epoch_D_Loss:0.1342 ||Epoch_G_Loss:0.1248 ||Epoch_E_Loss:0.1262
# timer:  0.1376 sec.
# -------------
# Epoch 185/1500
# -------------
# （train）
# -------------
# epoch 185 || Epoch_D_Loss:0.1363 ||Epoch_G_Loss:0.1180 ||Epoch_E_Loss:0.1329
# timer:  0.1361 sec.
# -------------
# Epoch 186/1500
# -------------
# （train）
# -------------
# epoch 186 || Epoch_D_Loss:0.1304 ||Epoch_G_Loss:0.1307 ||Epoch_E_Loss:0.1334
# timer:  0.1363 sec.
# -------------
# Epoch 187/1500
# -------------
# （train）
# -------------
# epoch 187 || Epoch_D_Loss:0.1228 ||Epoch_G_Loss:0.1390 ||Epoch_E_Loss:0.1381
# timer:  0.1368 sec.
# -------------
# Epoch 188/1500
# -------------
# （train）
# -------------
# epoch 188 || Epoch_D_Loss:0.1110 ||Epoch_G_Loss:0.1426 ||Epoch_E_Loss:0.1398
# timer:  0.1363 sec.
# -------------
# Epoch 189/1500
# -------------
# （train）
# -------------
# epoch 189 || Epoch_D_Loss:0.1056 ||Epoch_G_Loss:0.1399 ||Epoch_E_Loss:0.1510
# timer:  0.1376 sec.
# -------------
# Epoch 190/1500
# -------------
# （train）
# -------------
# epoch 190 || Epoch_D_Loss:0.1120 ||Epoch_G_Loss:0.1461 ||Epoch_E_Loss:0.1419
# timer:  0.1362 sec.
# -------------
# Epoch 191/1500
# -------------
# （train）
# -------------
# epoch 191 || Epoch_D_Loss:0.1147 ||Epoch_G_Loss:0.1417 ||Epoch_E_Loss:0.1426
# timer:  0.1381 sec.
# -------------
# Epoch 192/1500
# -------------
# （train）
# -------------
# epoch 192 || Epoch_D_Loss:0.1107 ||Epoch_G_Loss:0.1438 ||Epoch_E_Loss:0.1434
# timer:  0.1376 sec.
# -------------
# Epoch 193/1500
# -------------
# （train）
# -------------
# epoch 193 || Epoch_D_Loss:0.1098 ||Epoch_G_Loss:0.1295 ||Epoch_E_Loss:0.1499
# timer:  0.1369 sec.
# -------------
# Epoch 194/1500
# -------------
# （train）
# -------------
# epoch 194 || Epoch_D_Loss:0.1205 ||Epoch_G_Loss:0.1332 ||Epoch_E_Loss:0.1320
# timer:  0.1371 sec.
# -------------
# Epoch 195/1500
# -------------
# （train）
# -------------
# epoch 195 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.1495 ||Epoch_E_Loss:0.1435
# timer:  0.1387 sec.
# -------------
# Epoch 196/1500
# -------------
# （train）
# -------------
# epoch 196 || Epoch_D_Loss:0.1035 ||Epoch_G_Loss:0.1479 ||Epoch_E_Loss:0.1493
# timer:  0.1363 sec.
# -------------
# Epoch 197/1500
# -------------
# （train）
# -------------
# epoch 197 || Epoch_D_Loss:0.1015 ||Epoch_G_Loss:0.1432 ||Epoch_E_Loss:0.1529
# timer:  0.1383 sec.
# -------------
# Epoch 198/1500
# -------------
# （train）
# -------------
# epoch 198 || Epoch_D_Loss:0.1080 ||Epoch_G_Loss:0.1516 ||Epoch_E_Loss:0.1434
# timer:  0.1384 sec.
# -------------
# Epoch 199/1500
# -------------
# （train）
# -------------
# epoch 199 || Epoch_D_Loss:0.1089 ||Epoch_G_Loss:0.1499 ||Epoch_E_Loss:0.1404
# timer:  0.1356 sec.
# -------------
# Epoch 200/1500
# -------------
# （train）
# -------------
# epoch 200 || Epoch_D_Loss:0.1121 ||Epoch_G_Loss:0.1413 ||Epoch_E_Loss:0.1431
# timer:  0.1383 sec.
# -------------
# Epoch 201/1500
# -------------
# （train）
# -------------
# epoch 201 || Epoch_D_Loss:0.1218 ||Epoch_G_Loss:0.1324 ||Epoch_E_Loss:0.1301
# timer:  0.1358 sec.
# -------------
# Epoch 202/1500
# -------------
# （train）
# -------------
# epoch 202 || Epoch_D_Loss:0.1363 ||Epoch_G_Loss:0.1234 ||Epoch_E_Loss:0.1297
# timer:  0.1386 sec.
# -------------
# Epoch 203/1500
# -------------
# （train）
# -------------
# epoch 203 || Epoch_D_Loss:0.1362 ||Epoch_G_Loss:0.1181 ||Epoch_E_Loss:0.1303
# timer:  0.1365 sec.
# -------------
# Epoch 204/1500
# -------------
# （train）
# -------------
# epoch 204 || Epoch_D_Loss:0.1322 ||Epoch_G_Loss:0.1277 ||Epoch_E_Loss:0.1279
# timer:  0.1400 sec.
# -------------
# Epoch 205/1500
# -------------
# （train）
# -------------
# epoch 205 || Epoch_D_Loss:0.1231 ||Epoch_G_Loss:0.1145 ||Epoch_E_Loss:0.1425
# timer:  0.1361 sec.
# -------------
# Epoch 206/1500
# -------------
# （train）
# -------------
# epoch 206 || Epoch_D_Loss:0.1088 ||Epoch_G_Loss:0.1390 ||Epoch_E_Loss:0.1533
# timer:  0.1380 sec.
# -------------
# Epoch 207/1500
# -------------
# （train）
# -------------
# epoch 207 || Epoch_D_Loss:0.1035 ||Epoch_G_Loss:0.1521 ||Epoch_E_Loss:0.1529
# timer:  0.1375 sec.
# -------------
# Epoch 208/1500
# -------------
# （train）
# -------------
# epoch 208 || Epoch_D_Loss:0.1093 ||Epoch_G_Loss:0.1516 ||Epoch_E_Loss:0.1514
# timer:  0.1369 sec.
# -------------
# Epoch 209/1500
# -------------
# （train）
# -------------
# epoch 209 || Epoch_D_Loss:0.1271 ||Epoch_G_Loss:0.1207 ||Epoch_E_Loss:0.1384
# timer:  0.1371 sec.
# -------------
# Epoch 210/1500
# -------------
# （train）
# -------------
# epoch 210 || Epoch_D_Loss:0.1371 ||Epoch_G_Loss:0.1150 ||Epoch_E_Loss:0.1294
# timer:  0.1401 sec.
# -------------
# Epoch 211/1500
# -------------
# （train）
# -------------
# epoch 211 || Epoch_D_Loss:0.1203 ||Epoch_G_Loss:0.1368 ||Epoch_E_Loss:0.1410
# timer:  0.1354 sec.
# -------------
# Epoch 212/1500
# -------------
# （train）
# -------------
# epoch 212 || Epoch_D_Loss:0.1092 ||Epoch_G_Loss:0.1419 ||Epoch_E_Loss:0.1493
# timer:  0.1370 sec.
# -------------
# Epoch 213/1500
# -------------
# （train）
# -------------
# epoch 213 || Epoch_D_Loss:0.1139 ||Epoch_G_Loss:0.1393 ||Epoch_E_Loss:0.1437
# timer:  0.1389 sec.
# -------------
# Epoch 214/1500
# -------------
# （train）
# -------------
# epoch 214 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.1359 ||Epoch_E_Loss:0.1379
# timer:  0.1393 sec.
# -------------
# Epoch 215/1500
# -------------
# （train）
# -------------
# epoch 215 || Epoch_D_Loss:0.1210 ||Epoch_G_Loss:0.1320 ||Epoch_E_Loss:0.1352
# timer:  0.1372 sec.
# -------------
# Epoch 216/1500
# -------------
# （train）
# -------------
# epoch 216 || Epoch_D_Loss:0.1324 ||Epoch_G_Loss:0.1183 ||Epoch_E_Loss:0.1279
# timer:  0.1371 sec.
# -------------
# Epoch 217/1500
# -------------
# （train）
# -------------
# epoch 217 || Epoch_D_Loss:0.1466 ||Epoch_G_Loss:0.1007 ||Epoch_E_Loss:0.1177
# timer:  0.1388 sec.
# -------------
# Epoch 218/1500
# -------------
# （train）
# -------------
# epoch 218 || Epoch_D_Loss:0.1371 ||Epoch_G_Loss:0.1256 ||Epoch_E_Loss:0.1206
# timer:  0.1399 sec.
# -------------
# Epoch 219/1500
# -------------
# （train）
# -------------
# epoch 219 || Epoch_D_Loss:0.1206 ||Epoch_G_Loss:0.1202 ||Epoch_E_Loss:0.1338
# timer:  0.1368 sec.
# -------------
# Epoch 220/1500
# -------------
# （train）
# -------------
# epoch 220 || Epoch_D_Loss:0.1291 ||Epoch_G_Loss:0.1159 ||Epoch_E_Loss:0.1293
# timer:  0.1378 sec.
# -------------
# Epoch 221/1500
# -------------
# （train）
# -------------
# epoch 221 || Epoch_D_Loss:0.1506 ||Epoch_G_Loss:0.1096 ||Epoch_E_Loss:0.1200
# timer:  0.1356 sec.
# -------------
# Epoch 222/1500
# -------------
# （train）
# -------------
# epoch 222 || Epoch_D_Loss:0.1270 ||Epoch_G_Loss:0.1290 ||Epoch_E_Loss:0.1323
# timer:  0.1409 sec.
# -------------
# Epoch 223/1500
# -------------
# （train）
# -------------
# epoch 223 || Epoch_D_Loss:0.1081 ||Epoch_G_Loss:0.1541 ||Epoch_E_Loss:0.1468
# timer:  0.1341 sec.
# -------------
# Epoch 224/1500
# -------------
# （train）
# -------------
# epoch 224 || Epoch_D_Loss:0.1263 ||Epoch_G_Loss:0.1352 ||Epoch_E_Loss:0.1333
# timer:  0.1381 sec.
# -------------
# Epoch 225/1500
# -------------
# （train）
# -------------
# epoch 225 || Epoch_D_Loss:0.1524 ||Epoch_G_Loss:0.1038 ||Epoch_E_Loss:0.1158
# timer:  0.1368 sec.
# -------------
# Epoch 226/1500
# -------------
# （train）
# -------------
# epoch 226 || Epoch_D_Loss:0.1699 ||Epoch_G_Loss:0.0913 ||Epoch_E_Loss:0.1074
# timer:  0.1400 sec.
# -------------
# Epoch 227/1500
# -------------
# （train）
# -------------
# epoch 227 || Epoch_D_Loss:0.1389 ||Epoch_G_Loss:0.0998 ||Epoch_E_Loss:0.1260
# timer:  0.1370 sec.
# -------------
# Epoch 228/1500
# -------------
# （train）
# -------------
# epoch 228 || Epoch_D_Loss:0.1450 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1145
# timer:  0.1382 sec.
# -------------
# Epoch 229/1500
# -------------
# （train）
# -------------
# epoch 229 || Epoch_D_Loss:0.1401 ||Epoch_G_Loss:0.1026 ||Epoch_E_Loss:0.1246
# timer:  0.1355 sec.
# -------------
# Epoch 230/1500
# -------------
# （train）
# -------------
# epoch 230 || Epoch_D_Loss:0.1351 ||Epoch_G_Loss:0.1142 ||Epoch_E_Loss:0.1263
# timer:  0.1412 sec.
# -------------
# Epoch 231/1500
# -------------
# （train）
# -------------
# epoch 231 || Epoch_D_Loss:0.1383 ||Epoch_G_Loss:0.1195 ||Epoch_E_Loss:0.1220
# timer:  0.1390 sec.
# -------------
# Epoch 232/1500
# -------------
# （train）
# -------------
# epoch 232 || Epoch_D_Loss:0.1428 ||Epoch_G_Loss:0.1305 ||Epoch_E_Loss:0.1197
# timer:  0.1390 sec.
# -------------
# Epoch 233/1500
# -------------
# （train）
# -------------
# epoch 233 || Epoch_D_Loss:0.1245 ||Epoch_G_Loss:0.1303 ||Epoch_E_Loss:0.1289
# timer:  0.1415 sec.
# -------------
# Epoch 234/1500
# -------------
# （train）
# -------------
# epoch 234 || Epoch_D_Loss:0.1281 ||Epoch_G_Loss:0.1124 ||Epoch_E_Loss:0.1263
# timer:  0.1388 sec.
# -------------
# Epoch 235/1500
# -------------
# （train）
# -------------
# epoch 235 || Epoch_D_Loss:0.1372 ||Epoch_G_Loss:0.1102 ||Epoch_E_Loss:0.1183
# timer:  0.1356 sec.
# -------------
# Epoch 236/1500
# -------------
# （train）
# -------------
# epoch 236 || Epoch_D_Loss:0.1339 ||Epoch_G_Loss:0.1155 ||Epoch_E_Loss:0.1219
# timer:  0.1373 sec.
# -------------
# Epoch 237/1500
# -------------
# （train）
# -------------
# epoch 237 || Epoch_D_Loss:0.1326 ||Epoch_G_Loss:0.1064 ||Epoch_E_Loss:0.1242
# timer:  0.1349 sec.
# -------------
# Epoch 238/1500
# -------------
# （train）
# -------------
# epoch 238 || Epoch_D_Loss:0.1321 ||Epoch_G_Loss:0.1254 ||Epoch_E_Loss:0.1237
# timer:  0.1360 sec.
# -------------
# Epoch 239/1500
# -------------
# （train）
# -------------
# epoch 239 || Epoch_D_Loss:0.1277 ||Epoch_G_Loss:0.1113 ||Epoch_E_Loss:0.1285
# timer:  0.1396 sec.
# -------------
# Epoch 240/1500
# -------------
# （train）
# -------------
# epoch 240 || Epoch_D_Loss:0.1171 ||Epoch_G_Loss:0.1198 ||Epoch_E_Loss:0.1361
# timer:  0.1461 sec.
# -------------
# Epoch 241/1500
# -------------
# （train）
# -------------
# epoch 241 || Epoch_D_Loss:0.1275 ||Epoch_G_Loss:0.1316 ||Epoch_E_Loss:0.1246
# timer:  0.1379 sec.
# -------------
# Epoch 242/1500
# -------------
# （train）
# -------------
# epoch 242 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.1333 ||Epoch_E_Loss:0.1316
# timer:  0.1381 sec.
# -------------
# Epoch 243/1500
# -------------
# （train）
# -------------
# epoch 243 || Epoch_D_Loss:0.1251 ||Epoch_G_Loss:0.1315 ||Epoch_E_Loss:0.1300
# timer:  0.1342 sec.
# -------------
# Epoch 244/1500
# -------------
# （train）
# -------------
# epoch 244 || Epoch_D_Loss:0.1324 ||Epoch_G_Loss:0.1265 ||Epoch_E_Loss:0.1242
# timer:  0.1394 sec.
# -------------
# Epoch 245/1500
# -------------
# （train）
# -------------
# epoch 245 || Epoch_D_Loss:0.1309 ||Epoch_G_Loss:0.1341 ||Epoch_E_Loss:0.1261
# timer:  0.1367 sec.
# -------------
# Epoch 246/1500
# -------------
# （train）
# -------------
# epoch 246 || Epoch_D_Loss:0.1304 ||Epoch_G_Loss:0.1231 ||Epoch_E_Loss:0.1354
# timer:  0.1386 sec.
# -------------
# Epoch 247/1500
# -------------
# （train）
# -------------
# epoch 247 || Epoch_D_Loss:0.1329 ||Epoch_G_Loss:0.1306 ||Epoch_E_Loss:0.1275
# timer:  0.1385 sec.
# -------------
# Epoch 248/1500
# -------------
# （train）
# -------------
# epoch 248 || Epoch_D_Loss:0.1415 ||Epoch_G_Loss:0.1190 ||Epoch_E_Loss:0.1238
# timer:  0.1357 sec.
# -------------
# Epoch 249/1500
# -------------
# （train）
# -------------
# epoch 249 || Epoch_D_Loss:0.1515 ||Epoch_G_Loss:0.1309 ||Epoch_E_Loss:0.1182
# timer:  0.1356 sec.
# -------------
# Epoch 250/1500
# -------------
# （train）
# -------------
# epoch 250 || Epoch_D_Loss:0.1485 ||Epoch_G_Loss:0.1211 ||Epoch_E_Loss:0.1192
# timer:  0.1361 sec.
# -------------
# Epoch 251/1500
# -------------
# （train）
# -------------
# epoch 251 || Epoch_D_Loss:0.1365 ||Epoch_G_Loss:0.1170 ||Epoch_E_Loss:0.1258
# timer:  0.1354 sec.
# -------------
# Epoch 252/1500
# -------------
# （train）
# -------------
# epoch 252 || Epoch_D_Loss:0.1233 ||Epoch_G_Loss:0.1355 ||Epoch_E_Loss:0.1370
# timer:  0.1370 sec.
# -------------
# Epoch 253/1500
# -------------
# （train）
# -------------
# epoch 253 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.1388 ||Epoch_E_Loss:0.1404
# timer:  0.1353 sec.
# -------------
# Epoch 254/1500
# -------------
# （train）
# -------------
# epoch 254 || Epoch_D_Loss:0.1252 ||Epoch_G_Loss:0.1161 ||Epoch_E_Loss:0.1370
# timer:  0.1379 sec.
# -------------
# Epoch 255/1500
# -------------
# （train）
# -------------
# epoch 255 || Epoch_D_Loss:0.1525 ||Epoch_G_Loss:0.1143 ||Epoch_E_Loss:0.1224
# timer:  0.1343 sec.
# -------------
# Epoch 256/1500
# -------------
# （train）
# -------------
# epoch 256 || Epoch_D_Loss:0.1728 ||Epoch_G_Loss:0.1019 ||Epoch_E_Loss:0.1072
# timer:  0.1368 sec.
# -------------
# Epoch 257/1500
# -------------
# （train）
# -------------
# epoch 257 || Epoch_D_Loss:0.1566 ||Epoch_G_Loss:0.1073 ||Epoch_E_Loss:0.1150
# timer:  0.1344 sec.
# -------------
# Epoch 258/1500
# -------------
# （train）
# -------------
# epoch 258 || Epoch_D_Loss:0.1404 ||Epoch_G_Loss:0.1164 ||Epoch_E_Loss:0.1215
# timer:  0.1366 sec.
# -------------
# Epoch 259/1500
# -------------
# （train）
# -------------
# epoch 259 || Epoch_D_Loss:0.1309 ||Epoch_G_Loss:0.1211 ||Epoch_E_Loss:0.1254
# timer:  0.1344 sec.
# -------------
# Epoch 260/1500
# -------------
# （train）
# -------------
# epoch 260 || Epoch_D_Loss:0.1332 ||Epoch_G_Loss:0.1168 ||Epoch_E_Loss:0.1282
# timer:  0.1365 sec.
# -------------
# Epoch 261/1500
# -------------
# （train）
# -------------
# epoch 261 || Epoch_D_Loss:0.1345 ||Epoch_G_Loss:0.1144 ||Epoch_E_Loss:0.1218
# timer:  0.1346 sec.
# -------------
# Epoch 262/1500
# -------------
# （train）
# -------------
# epoch 262 || Epoch_D_Loss:0.1424 ||Epoch_G_Loss:0.1207 ||Epoch_E_Loss:0.1141
# timer:  0.1416 sec.
# -------------
# Epoch 263/1500
# -------------
# （train）
# -------------
# epoch 263 || Epoch_D_Loss:0.1180 ||Epoch_G_Loss:0.1274 ||Epoch_E_Loss:0.1391
# timer:  0.1343 sec.
# -------------
# Epoch 264/1500
# -------------
# （train）
# -------------
# epoch 264 || Epoch_D_Loss:0.1099 ||Epoch_G_Loss:0.1412 ||Epoch_E_Loss:0.1378
# timer:  0.1362 sec.
# -------------
# Epoch 265/1500
# -------------
# （train）
# -------------
# epoch 265 || Epoch_D_Loss:0.1204 ||Epoch_G_Loss:0.1398 ||Epoch_E_Loss:0.1325
# timer:  0.1342 sec.
# -------------
# Epoch 266/1500
# -------------
# （train）
# -------------
# epoch 266 || Epoch_D_Loss:0.1413 ||Epoch_G_Loss:0.1235 ||Epoch_E_Loss:0.1200
# timer:  0.1371 sec.
# -------------
# Epoch 267/1500
# -------------
# （train）
# -------------
# epoch 267 || Epoch_D_Loss:0.1431 ||Epoch_G_Loss:0.1083 ||Epoch_E_Loss:0.1197
# timer:  0.1341 sec.
# -------------
# Epoch 268/1500
# -------------
# （train）
# -------------
# epoch 268 || Epoch_D_Loss:0.1523 ||Epoch_G_Loss:0.0981 ||Epoch_E_Loss:0.1181
# timer:  0.1359 sec.
# -------------
# Epoch 269/1500
# -------------
# （train）
# -------------
# epoch 269 || Epoch_D_Loss:0.1621 ||Epoch_G_Loss:0.1070 ||Epoch_E_Loss:0.1066
# timer:  0.1365 sec.
# -------------
# Epoch 270/1500
# -------------
# （train）
# -------------
# epoch 270 || Epoch_D_Loss:0.1529 ||Epoch_G_Loss:0.0957 ||Epoch_E_Loss:0.1167
# timer:  0.1369 sec.
# -------------
# Epoch 271/1500
# -------------
# （train）
# -------------
# epoch 271 || Epoch_D_Loss:0.1399 ||Epoch_G_Loss:0.1086 ||Epoch_E_Loss:0.1217
# timer:  0.1350 sec.
# -------------
# Epoch 272/1500
# -------------
# （train）
# -------------
# epoch 272 || Epoch_D_Loss:0.1287 ||Epoch_G_Loss:0.1224 ||Epoch_E_Loss:0.1261
# timer:  0.1389 sec.
# -------------
# Epoch 273/1500
# -------------
# （train）
# -------------
# epoch 273 || Epoch_D_Loss:0.1269 ||Epoch_G_Loss:0.1156 ||Epoch_E_Loss:0.1308
# timer:  0.1377 sec.
# -------------
# Epoch 274/1500
# -------------
# （train）
# -------------
# epoch 274 || Epoch_D_Loss:0.1481 ||Epoch_G_Loss:0.0963 ||Epoch_E_Loss:0.1188
# timer:  0.1369 sec.
# -------------
# Epoch 275/1500
# -------------
# （train）
# -------------
# epoch 275 || Epoch_D_Loss:0.1587 ||Epoch_G_Loss:0.0953 ||Epoch_E_Loss:0.1114
# timer:  0.1353 sec.
# -------------
# Epoch 276/1500
# -------------
# （train）
# -------------
# epoch 276 || Epoch_D_Loss:0.1510 ||Epoch_G_Loss:0.1050 ||Epoch_E_Loss:0.1186
# timer:  0.1357 sec.
# -------------
# Epoch 277/1500
# -------------
# （train）
# -------------
# epoch 277 || Epoch_D_Loss:0.1245 ||Epoch_G_Loss:0.1170 ||Epoch_E_Loss:0.1345
# timer:  0.1350 sec.
# -------------
# Epoch 278/1500
# -------------
# （train）
# -------------
# epoch 278 || Epoch_D_Loss:0.1242 ||Epoch_G_Loss:0.1271 ||Epoch_E_Loss:0.1316
# timer:  0.1393 sec.
# -------------
# Epoch 279/1500
# -------------
# （train）
# -------------
# epoch 279 || Epoch_D_Loss:0.1448 ||Epoch_G_Loss:0.0959 ||Epoch_E_Loss:0.1175
# timer:  0.1357 sec.
# -------------
# Epoch 280/1500
# -------------
# （train）
# -------------
# epoch 280 || Epoch_D_Loss:0.1772 ||Epoch_G_Loss:0.0874 ||Epoch_E_Loss:0.0997
# timer:  0.1360 sec.
# -------------
# Epoch 281/1500
# -------------
# （train）
# -------------
# epoch 281 || Epoch_D_Loss:0.2027 ||Epoch_G_Loss:0.0746 ||Epoch_E_Loss:0.0894
# timer:  0.1351 sec.
# -------------
# Epoch 282/1500
# -------------
# （train）
# -------------
# epoch 282 || Epoch_D_Loss:0.1961 ||Epoch_G_Loss:0.0839 ||Epoch_E_Loss:0.0899
# timer:  0.1370 sec.
# -------------
# Epoch 283/1500
# -------------
# （train）
# -------------
# epoch 283 || Epoch_D_Loss:0.1431 ||Epoch_G_Loss:0.1115 ||Epoch_E_Loss:0.1139
# timer:  0.1359 sec.
# -------------
# Epoch 284/1500
# -------------
# （train）
# -------------
# epoch 284 || Epoch_D_Loss:0.1112 ||Epoch_G_Loss:0.1209 ||Epoch_E_Loss:0.1368
# timer:  0.1425 sec.
# -------------
# Epoch 285/1500
# -------------
# （train）
# -------------
# epoch 285 || Epoch_D_Loss:0.1276 ||Epoch_G_Loss:0.1110 ||Epoch_E_Loss:0.1226
# timer:  0.1390 sec.
# -------------
# Epoch 286/1500
# -------------
# （train）
# -------------
# epoch 286 || Epoch_D_Loss:0.1406 ||Epoch_G_Loss:0.1035 ||Epoch_E_Loss:0.1114
# timer:  0.1377 sec.
# -------------
# Epoch 287/1500
# -------------
# （train）
# -------------
# epoch 287 || Epoch_D_Loss:0.1378 ||Epoch_G_Loss:0.0896 ||Epoch_E_Loss:0.1115
# timer:  0.1382 sec.
# -------------
# Epoch 288/1500
# -------------
# （train）
# -------------
# epoch 288 || Epoch_D_Loss:0.1381 ||Epoch_G_Loss:0.1070 ||Epoch_E_Loss:0.1103
# timer:  0.1381 sec.
# -------------
# Epoch 289/1500
# -------------
# （train）
# -------------
# epoch 289 || Epoch_D_Loss:0.1270 ||Epoch_G_Loss:0.0987 ||Epoch_E_Loss:0.1154
# timer:  0.1390 sec.
# -------------
# Epoch 290/1500
# -------------
# （train）
# -------------
# epoch 290 || Epoch_D_Loss:0.1341 ||Epoch_G_Loss:0.1046 ||Epoch_E_Loss:0.1108
# timer:  0.1389 sec.
# -------------
# Epoch 291/1500
# -------------
# （train）
# -------------
# epoch 291 || Epoch_D_Loss:0.1300 ||Epoch_G_Loss:0.1047 ||Epoch_E_Loss:0.1158
# timer:  0.1384 sec.
# -------------
# Epoch 292/1500
# -------------
# （train）
# -------------
# epoch 292 || Epoch_D_Loss:0.1314 ||Epoch_G_Loss:0.1123 ||Epoch_E_Loss:0.1141
# timer:  0.1386 sec.
# -------------
# Epoch 293/1500
# -------------
# （train）
# -------------
# epoch 293 || Epoch_D_Loss:0.1262 ||Epoch_G_Loss:0.1130 ||Epoch_E_Loss:0.1232
# timer:  0.1392 sec.
# -------------
# Epoch 294/1500
# -------------
# （train）
# -------------
# epoch 294 || Epoch_D_Loss:0.1232 ||Epoch_G_Loss:0.1232 ||Epoch_E_Loss:0.1267
# timer:  0.1434 sec.
# -------------
# Epoch 295/1500
# -------------
# （train）
# -------------
# epoch 295 || Epoch_D_Loss:0.1267 ||Epoch_G_Loss:0.1224 ||Epoch_E_Loss:0.1263
# timer:  0.1351 sec.
# -------------
# Epoch 296/1500
# -------------
# （train）
# -------------
# epoch 296 || Epoch_D_Loss:0.1350 ||Epoch_G_Loss:0.1073 ||Epoch_E_Loss:0.1187
# timer:  0.1359 sec.
# -------------
# Epoch 297/1500
# -------------
# （train）
# -------------
# ...
# timer:  0.1369 sec.
# -------------
# Epoch 1403/1500
# -------------
# （train）
# -------------
# epoch 1403 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.1621 ||Epoch_E_Loss:0.1590
# timer:  0.1348 sec.
# -------------
# Epoch 1404/1500
# -------------
# （train）
# -------------
# epoch 1404 || Epoch_D_Loss:0.0944 ||Epoch_G_Loss:0.1642 ||Epoch_E_Loss:0.1489
# timer:  0.1390 sec.
# -------------
# Epoch 1405/1500
# -------------
# （train）
# -------------
# epoch 1405 || Epoch_D_Loss:0.0990 ||Epoch_G_Loss:0.1410 ||Epoch_E_Loss:0.1450
# timer:  0.1343 sec.
# -------------
# Epoch 1406/1500
# -------------
# （train）
# -------------
# epoch 1406 || Epoch_D_Loss:0.1037 ||Epoch_G_Loss:0.1524 ||Epoch_E_Loss:0.1488
# timer:  0.1369 sec.
# -------------
# Epoch 1407/1500
# -------------
# （train）
# -------------
# epoch 1407 || Epoch_D_Loss:0.0835 ||Epoch_G_Loss:0.1465 ||Epoch_E_Loss:0.1590
# timer:  0.1344 sec.
# -------------
# Epoch 1408/1500
# -------------
# （train）
# -------------
# epoch 1408 || Epoch_D_Loss:0.0837 ||Epoch_G_Loss:0.1659 ||Epoch_E_Loss:0.1584
# timer:  0.1416 sec.
# -------------
# Epoch 1409/1500
# -------------
# （train）
# -------------
# epoch 1409 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1574 ||Epoch_E_Loss:0.1595
# timer:  0.1358 sec.
# -------------
# Epoch 1410/1500
# -------------
# （train）
# -------------
# epoch 1410 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.1602 ||Epoch_E_Loss:0.1712
# timer:  0.1369 sec.
# -------------
# Epoch 1411/1500
# -------------
# （train）
# -------------
# epoch 1411 || Epoch_D_Loss:0.0842 ||Epoch_G_Loss:0.1679 ||Epoch_E_Loss:0.1645
# timer:  0.1350 sec.
# -------------
# Epoch 1412/1500
# -------------
# （train）
# -------------
# epoch 1412 || Epoch_D_Loss:0.0828 ||Epoch_G_Loss:0.1538 ||Epoch_E_Loss:0.1583
# timer:  0.1371 sec.
# -------------
# Epoch 1413/1500
# -------------
# （train）
# -------------
# epoch 1413 || Epoch_D_Loss:0.0950 ||Epoch_G_Loss:0.1533 ||Epoch_E_Loss:0.1488
# timer:  0.1345 sec.
# -------------
# Epoch 1414/1500
# -------------
# （train）
# -------------
# epoch 1414 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1438 ||Epoch_E_Loss:0.1536
# timer:  0.1376 sec.
# -------------
# Epoch 1415/1500
# -------------
# （train）
# -------------
# epoch 1415 || Epoch_D_Loss:0.0912 ||Epoch_G_Loss:0.1534 ||Epoch_E_Loss:0.1569
# timer:  0.1349 sec.
# -------------
# Epoch 1416/1500
# -------------
# （train）
# -------------
# epoch 1416 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.1645 ||Epoch_E_Loss:0.1652
# timer:  0.1372 sec.
# -------------
# Epoch 1417/1500
# -------------
# （train）
# -------------
# epoch 1417 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.1684 ||Epoch_E_Loss:0.1632
# timer:  0.1351 sec.
# -------------
# Epoch 1418/1500
# -------------
# （train）
# -------------
# epoch 1418 || Epoch_D_Loss:0.0800 ||Epoch_G_Loss:0.1636 ||Epoch_E_Loss:0.1727
# timer:  0.1378 sec.
# -------------
# Epoch 1419/1500
# -------------
# （train）
# -------------
# epoch 1419 || Epoch_D_Loss:0.0894 ||Epoch_G_Loss:0.1503 ||Epoch_E_Loss:0.1601
# timer:  0.1359 sec.
# -------------
# Epoch 1420/1500
# -------------
# （train）
# -------------
# epoch 1420 || Epoch_D_Loss:0.0980 ||Epoch_G_Loss:0.1385 ||Epoch_E_Loss:0.1533
# timer:  0.1389 sec.
# -------------
# Epoch 1421/1500
# -------------
# （train）
# -------------
# epoch 1421 || Epoch_D_Loss:0.0971 ||Epoch_G_Loss:0.1381 ||Epoch_E_Loss:0.1582
# timer:  0.1361 sec.
# -------------
# Epoch 1422/1500
# -------------
# （train）
# -------------
# epoch 1422 || Epoch_D_Loss:0.1050 ||Epoch_G_Loss:0.1611 ||Epoch_E_Loss:0.1510
# timer:  0.1405 sec.
# -------------
# Epoch 1423/1500
# -------------
# （train）
# -------------
# epoch 1423 || Epoch_D_Loss:0.0853 ||Epoch_G_Loss:0.1571 ||Epoch_E_Loss:0.1566
# timer:  0.1345 sec.
# -------------
# Epoch 1424/1500
# -------------
# （train）
# -------------
# epoch 1424 || Epoch_D_Loss:0.0808 ||Epoch_G_Loss:0.1736 ||Epoch_E_Loss:0.1625
# timer:  0.1390 sec.
# -------------
# Epoch 1425/1500
# -------------
# （train）
# -------------
# epoch 1425 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.1732 ||Epoch_E_Loss:0.1789
# timer:  0.1356 sec.
# -------------
# Epoch 1426/1500
# -------------
# （train）
# -------------
# epoch 1426 || Epoch_D_Loss:0.0794 ||Epoch_G_Loss:0.1610 ||Epoch_E_Loss:0.1709
# timer:  0.1367 sec.
# -------------
# Epoch 1427/1500
# -------------
# （train）
# -------------
# epoch 1427 || Epoch_D_Loss:0.0869 ||Epoch_G_Loss:0.1547 ||Epoch_E_Loss:0.1566
# timer:  0.1387 sec.
# -------------
# Epoch 1428/1500
# -------------
# （train）
# -------------
# epoch 1428 || Epoch_D_Loss:0.0877 ||Epoch_G_Loss:0.1494 ||Epoch_E_Loss:0.1613
# timer:  0.1373 sec.
# -------------
# Epoch 1429/1500
# -------------
# （train）
# -------------
# epoch 1429 || Epoch_D_Loss:0.0869 ||Epoch_G_Loss:0.1546 ||Epoch_E_Loss:0.1566
# timer:  0.1350 sec.
# -------------
# Epoch 1430/1500
# -------------
# （train）
# -------------
# epoch 1430 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1535 ||Epoch_E_Loss:0.1626
# timer:  0.1372 sec.
# -------------
# Epoch 1431/1500
# -------------
# （train）
# -------------
# epoch 1431 || Epoch_D_Loss:0.0762 ||Epoch_G_Loss:0.1588 ||Epoch_E_Loss:0.1699
# timer:  0.1348 sec.
# -------------
# Epoch 1432/1500
# -------------
# （train）
# -------------
# epoch 1432 || Epoch_D_Loss:0.0827 ||Epoch_G_Loss:0.1705 ||Epoch_E_Loss:0.1636
# timer:  0.1386 sec.
# -------------
# Epoch 1433/1500
# -------------
# （train）
# -------------
# epoch 1433 || Epoch_D_Loss:0.0810 ||Epoch_G_Loss:0.1740 ||Epoch_E_Loss:0.1605
# timer:  0.1365 sec.
# -------------
# Epoch 1434/1500
# -------------
# （train）
# -------------
# epoch 1434 || Epoch_D_Loss:0.0830 ||Epoch_G_Loss:0.1557 ||Epoch_E_Loss:0.1578
# timer:  0.1377 sec.
# -------------
# Epoch 1435/1500
# -------------
# （train）
# -------------
# epoch 1435 || Epoch_D_Loss:0.0975 ||Epoch_G_Loss:0.1506 ||Epoch_E_Loss:0.1600
# timer:  0.1344 sec.
# -------------
# Epoch 1436/1500
# -------------
# （train）
# -------------
# epoch 1436 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.1538 ||Epoch_E_Loss:0.1585
# timer:  0.1368 sec.
# -------------
# Epoch 1437/1500
# -------------
# （train）
# -------------
# epoch 1437 || Epoch_D_Loss:0.0841 ||Epoch_G_Loss:0.1524 ||Epoch_E_Loss:0.1554
# timer:  0.1351 sec.
# -------------
# Epoch 1438/1500
# -------------
# （train）
# -------------
# epoch 1438 || Epoch_D_Loss:0.0829 ||Epoch_G_Loss:0.1528 ||Epoch_E_Loss:0.1557
# timer:  0.1408 sec.
# -------------
# Epoch 1439/1500
# -------------
# （train）
# -------------
# epoch 1439 || Epoch_D_Loss:0.0846 ||Epoch_G_Loss:0.1609 ||Epoch_E_Loss:0.1747
# timer:  0.1345 sec.
# -------------
# Epoch 1440/1500
# -------------
# （train）
# -------------
# epoch 1440 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1634 ||Epoch_E_Loss:0.1623
# timer:  0.1414 sec.
# -------------
# Epoch 1441/1500
# -------------
# （train）
# -------------
# epoch 1441 || Epoch_D_Loss:0.0870 ||Epoch_G_Loss:0.1372 ||Epoch_E_Loss:0.1657
# timer:  0.1422 sec.
# -------------
# Epoch 1442/1500
# -------------
# （train）
# -------------
# epoch 1442 || Epoch_D_Loss:0.0909 ||Epoch_G_Loss:0.1515 ||Epoch_E_Loss:0.1500
# timer:  0.1397 sec.
# -------------
# Epoch 1443/1500
# -------------
# （train）
# -------------
# epoch 1443 || Epoch_D_Loss:0.0937 ||Epoch_G_Loss:0.1393 ||Epoch_E_Loss:0.1698
# timer:  0.1384 sec.
# -------------
# Epoch 1444/1500
# -------------
# （train）
# -------------
# epoch 1444 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.1532 ||Epoch_E_Loss:0.1695
# timer:  0.1359 sec.
# -------------
# Epoch 1445/1500
# -------------
# （train）
# -------------
# epoch 1445 || Epoch_D_Loss:0.0939 ||Epoch_G_Loss:0.1538 ||Epoch_E_Loss:0.1519
# timer:  0.1343 sec.
# -------------
# Epoch 1446/1500
# -------------
# （train）
# -------------
# epoch 1446 || Epoch_D_Loss:0.0942 ||Epoch_G_Loss:0.1374 ||Epoch_E_Loss:0.1539
# timer:  0.1363 sec.
# -------------
# Epoch 1447/1500
# -------------
# （train）
# -------------
# epoch 1447 || Epoch_D_Loss:0.1080 ||Epoch_G_Loss:0.1327 ||Epoch_E_Loss:0.1559
# timer:  0.1341 sec.
# -------------
# Epoch 1448/1500
# -------------
# （train）
# -------------
# epoch 1448 || Epoch_D_Loss:0.0999 ||Epoch_G_Loss:0.1388 ||Epoch_E_Loss:0.1529
# timer:  0.1386 sec.
# -------------
# Epoch 1449/1500
# -------------
# （train）
# -------------
# epoch 1449 || Epoch_D_Loss:0.0801 ||Epoch_G_Loss:0.1703 ||Epoch_E_Loss:0.1619
# timer:  0.1345 sec.
# -------------
# Epoch 1450/1500
# -------------
# （train）
# -------------
# epoch 1450 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.1505 ||Epoch_E_Loss:0.1652
# timer:  0.1363 sec.
# -------------
# Epoch 1451/1500
# -------------
# （train）
# -------------
# epoch 1451 || Epoch_D_Loss:0.0750 ||Epoch_G_Loss:0.1584 ||Epoch_E_Loss:0.1678
# timer:  0.1340 sec.
# -------------
# Epoch 1452/1500
# -------------
# （train）
# -------------
# epoch 1452 || Epoch_D_Loss:0.0780 ||Epoch_G_Loss:0.1544 ||Epoch_E_Loss:0.1688
# timer:  0.1374 sec.
# -------------
# Epoch 1453/1500
# -------------
# （train）
# -------------
# epoch 1453 || Epoch_D_Loss:0.0791 ||Epoch_G_Loss:0.1401 ||Epoch_E_Loss:0.1724
# timer:  0.1364 sec.
# -------------
# Epoch 1454/1500
# -------------
# （train）
# -------------
# epoch 1454 || Epoch_D_Loss:0.0848 ||Epoch_G_Loss:0.1605 ||Epoch_E_Loss:0.1602
# timer:  0.1361 sec.
# -------------
# Epoch 1455/1500
# -------------
# （train）
# -------------
# epoch 1455 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.1647 ||Epoch_E_Loss:0.1737
# timer:  0.1338 sec.
# -------------
# Epoch 1456/1500
# -------------
# （train）
# -------------
# epoch 1456 || Epoch_D_Loss:0.0783 ||Epoch_G_Loss:0.1634 ||Epoch_E_Loss:0.1740
# timer:  0.1368 sec.
# -------------
# Epoch 1457/1500
# -------------
# （train）
# -------------
# epoch 1457 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.1682 ||Epoch_E_Loss:0.1561
# timer:  0.1398 sec.
# -------------
# Epoch 1458/1500
# -------------
# （train）
# -------------
# epoch 1458 || Epoch_D_Loss:0.0831 ||Epoch_G_Loss:0.1549 ||Epoch_E_Loss:0.1559
# timer:  0.1357 sec.
# -------------
# Epoch 1459/1500
# -------------
# （train）
# -------------
# epoch 1459 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.1378 ||Epoch_E_Loss:0.1528
# timer:  0.1339 sec.
# -------------
# Epoch 1460/1500
# -------------
# （train）
# -------------
# epoch 1460 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.1333 ||Epoch_E_Loss:0.1616
# timer:  0.1363 sec.
# -------------
# Epoch 1461/1500
# -------------
# （train）
# -------------
# epoch 1461 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.1809 ||Epoch_E_Loss:0.1636
# timer:  0.1341 sec.
# -------------
# Epoch 1462/1500
# -------------
# （train）
# -------------
# epoch 1462 || Epoch_D_Loss:0.0742 ||Epoch_G_Loss:0.1731 ||Epoch_E_Loss:0.1782
# timer:  0.1363 sec.
# -------------
# Epoch 1463/1500
# -------------
# （train）
# -------------
# epoch 1463 || Epoch_D_Loss:0.0756 ||Epoch_G_Loss:0.1519 ||Epoch_E_Loss:0.1724
# timer:  0.1361 sec.
# -------------
# Epoch 1464/1500
# -------------
# （train）
# -------------
# epoch 1464 || Epoch_D_Loss:0.0862 ||Epoch_G_Loss:0.1478 ||Epoch_E_Loss:0.1747
# timer:  0.1367 sec.
# -------------
# Epoch 1465/1500
# -------------
# （train）
# -------------
# epoch 1465 || Epoch_D_Loss:0.0981 ||Epoch_G_Loss:0.1561 ||Epoch_E_Loss:0.1617
# timer:  0.1338 sec.
# -------------
# Epoch 1466/1500
# -------------
# （train）
# -------------
# epoch 1466 || Epoch_D_Loss:0.0874 ||Epoch_G_Loss:0.1512 ||Epoch_E_Loss:0.1602
# timer:  0.1400 sec.
# -------------
# Epoch 1467/1500
# -------------
# （train）
# -------------
# epoch 1467 || Epoch_D_Loss:0.0911 ||Epoch_G_Loss:0.1611 ||Epoch_E_Loss:0.1530
# timer:  0.1375 sec.
# -------------
# Epoch 1468/1500
# -------------
# （train）
# -------------
# epoch 1468 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.1536 ||Epoch_E_Loss:0.1666
# timer:  0.1356 sec.
# -------------
# Epoch 1469/1500
# -------------
# （train）
# -------------
# epoch 1469 || Epoch_D_Loss:0.0921 ||Epoch_G_Loss:0.1552 ||Epoch_E_Loss:0.1553
# timer:  0.1338 sec.
# -------------
# Epoch 1470/1500
# -------------
# （train）
# -------------
# epoch 1470 || Epoch_D_Loss:0.0844 ||Epoch_G_Loss:0.1322 ||Epoch_E_Loss:0.1657
# timer:  0.1359 sec.
# -------------
# Epoch 1471/1500
# -------------
# （train）
# -------------
# epoch 1471 || Epoch_D_Loss:0.0897 ||Epoch_G_Loss:0.1486 ||Epoch_E_Loss:0.1541
# timer:  0.1340 sec.
# -------------
# Epoch 1472/1500
# -------------
# （train）
# -------------
# epoch 1472 || Epoch_D_Loss:0.0844 ||Epoch_G_Loss:0.1726 ||Epoch_E_Loss:0.1599
# timer:  0.1362 sec.
# -------------
# Epoch 1473/1500
# -------------
# （train）
# -------------
# epoch 1473 || Epoch_D_Loss:0.0683 ||Epoch_G_Loss:0.1499 ||Epoch_E_Loss:0.1837
# timer:  0.1399 sec.
# -------------
# Epoch 1474/1500
# -------------
# （train）
# -------------
# epoch 1474 || Epoch_D_Loss:0.0769 ||Epoch_G_Loss:0.1527 ||Epoch_E_Loss:0.1675
# timer:  0.1364 sec.
# -------------
# Epoch 1475/1500
# -------------
# （train）
# -------------
# epoch 1475 || Epoch_D_Loss:0.0893 ||Epoch_G_Loss:0.1601 ||Epoch_E_Loss:0.1616
# timer:  0.1341 sec.
# -------------
# Epoch 1476/1500
# -------------
# （train）
# -------------
# epoch 1476 || Epoch_D_Loss:0.0855 ||Epoch_G_Loss:0.1614 ||Epoch_E_Loss:0.1593
# timer:  0.1357 sec.
# -------------
# Epoch 1477/1500
# -------------
# （train）
# -------------
# epoch 1477 || Epoch_D_Loss:0.0853 ||Epoch_G_Loss:0.1655 ||Epoch_E_Loss:0.1585
# timer:  0.1342 sec.
# -------------
# Epoch 1478/1500
# -------------
# （train）
# -------------
# epoch 1478 || Epoch_D_Loss:0.0884 ||Epoch_G_Loss:0.1599 ||Epoch_E_Loss:0.1623
# timer:  0.1392 sec.
# -------------
# Epoch 1479/1500
# -------------
# （train）
# -------------
# epoch 1479 || Epoch_D_Loss:0.0840 ||Epoch_G_Loss:0.1548 ||Epoch_E_Loss:0.1681
# timer:  0.1340 sec.
# -------------
# Epoch 1480/1500
# -------------
# （train）
# -------------
# epoch 1480 || Epoch_D_Loss:0.0786 ||Epoch_G_Loss:0.1628 ||Epoch_E_Loss:0.1618
# timer:  0.1357 sec.
# -------------
# Epoch 1481/1500
# -------------
# （train）
# -------------
# epoch 1481 || Epoch_D_Loss:0.0747 ||Epoch_G_Loss:0.1520 ||Epoch_E_Loss:0.1692
# timer:  0.1356 sec.
# -------------
# Epoch 1482/1500
# -------------
# （train）
# -------------
# epoch 1482 || Epoch_D_Loss:0.0743 ||Epoch_G_Loss:0.1656 ||Epoch_E_Loss:0.1718
# timer:  0.1396 sec.
# -------------
# Epoch 1483/1500
# -------------
# （train）
# -------------
# epoch 1483 || Epoch_D_Loss:0.0845 ||Epoch_G_Loss:0.1568 ||Epoch_E_Loss:0.1622
# timer:  0.1389 sec.
# -------------
# Epoch 1484/1500
# -------------
# （train）
# -------------
# epoch 1484 || Epoch_D_Loss:0.0883 ||Epoch_G_Loss:0.1535 ||Epoch_E_Loss:0.1571
# timer:  0.1357 sec.
# -------------
# Epoch 1485/1500
# -------------
# （train）
# -------------
# epoch 1485 || Epoch_D_Loss:0.0838 ||Epoch_G_Loss:0.1595 ||Epoch_E_Loss:0.1621
# timer:  0.1343 sec.
# -------------
# Epoch 1486/1500
# -------------
# （train）
# -------------
# epoch 1486 || Epoch_D_Loss:0.0870 ||Epoch_G_Loss:0.1462 ||Epoch_E_Loss:0.1747
# timer:  0.1348 sec.
# -------------
# Epoch 1487/1500
# -------------
# （train）
# -------------
# epoch 1487 || Epoch_D_Loss:0.0927 ||Epoch_G_Loss:0.1553 ||Epoch_E_Loss:0.1538
# timer:  0.1364 sec.
# -------------
# Epoch 1488/1500
# -------------
# （train）
# -------------
# epoch 1488 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1505 ||Epoch_E_Loss:0.1591
# timer:  0.1369 sec.
# -------------
# Epoch 1489/1500
# -------------
# （train）
# -------------
# epoch 1489 || Epoch_D_Loss:0.0836 ||Epoch_G_Loss:0.1595 ||Epoch_E_Loss:0.1650
# timer:  0.1383 sec.
# -------------
# Epoch 1490/1500
# -------------
# （train）
# -------------
# epoch 1490 || Epoch_D_Loss:0.0778 ||Epoch_G_Loss:0.1522 ||Epoch_E_Loss:0.1718
# timer:  0.1365 sec.
# -------------
# Epoch 1491/1500
# -------------
# （train）
# -------------
# epoch 1491 || Epoch_D_Loss:0.0913 ||Epoch_G_Loss:0.1601 ||Epoch_E_Loss:0.1654
# timer:  0.1342 sec.
# -------------
# Epoch 1492/1500
# -------------
# （train）
# -------------
# epoch 1492 || Epoch_D_Loss:0.0890 ||Epoch_G_Loss:0.1500 ||Epoch_E_Loss:0.1557
# timer:  0.1377 sec.
# -------------
# Epoch 1493/1500
# -------------
# （train）
# -------------
# epoch 1493 || Epoch_D_Loss:0.0885 ||Epoch_G_Loss:0.1353 ||Epoch_E_Loss:0.1677
# timer:  0.1351 sec.
# -------------
# Epoch 1494/1500
# -------------
# （train）
# -------------
# epoch 1494 || Epoch_D_Loss:0.0826 ||Epoch_G_Loss:0.1562 ||Epoch_E_Loss:0.1663
# timer:  0.1395 sec.
# -------------
# Epoch 1495/1500
# -------------
# （train）
# -------------
# epoch 1495 || Epoch_D_Loss:0.0784 ||Epoch_G_Loss:0.1816 ||Epoch_E_Loss:0.1575
# timer:  0.1375 sec.
# -------------
# Epoch 1496/1500
# -------------
# （train）
# -------------
# epoch 1496 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.1495 ||Epoch_E_Loss:0.1681
# timer:  0.1352 sec.
# -------------
# Epoch 1497/1500
# -------------
# （train）
# -------------
# epoch 1497 || Epoch_D_Loss:0.0822 ||Epoch_G_Loss:0.1563 ||Epoch_E_Loss:0.1578
# timer:  0.1339 sec.
# -------------
# Epoch 1498/1500
# -------------
# （train）
# -------------
# epoch 1498 || Epoch_D_Loss:0.0879 ||Epoch_G_Loss:0.1387 ||Epoch_E_Loss:0.1786
# timer:  0.1360 sec.
# -------------
# Epoch 1499/1500
# -------------
# （train）
# -------------
# epoch 1499 || Epoch_D_Loss:0.0824 ||Epoch_G_Loss:0.1662 ||Epoch_E_Loss:0.1688
# timer:  0.1359 sec.
# 総イテレーション回数: 10501

# %%
# 生成画像と訓練データを可視化する
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
G_update.eval()
fake_images = G_update(fixed_z.to(device))

batch_iterator = iter(train_dataloader)
imges = next(batch_iterator)

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')
    
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(5):
        img_path = "./data/test_28size/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test_28size/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()

mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std)
)

batch_size = 5

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False
)

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)
imges = next(batch_iterator)

fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, z_out_real, D, Lambda=0.1):
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    _, x_feature = D(x, z_out_real)
    _, G_feature = D(fake_img, z_out_real)

    discrimination_loss = torch.abs(x_feature-G_feature)
    discrimination_loss = discrimination_loss.view(
        discrimination_loss.size()[0], -1
    )
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
x = imges[0:5]
x = x.to(device)

E_update.eval()
G_update.eval()
z_out_real = E_update(imges.to(device))
imges_reconstruct = G_update(z_out_real)

loss, loss_each, residual_loss_each = Anomaly_score(
    x, imges_reconstruct, z_out_real, D_update, Lambda=0.1
)

loss_each = loss_each.cpu().detach().numpy()
print("total loss: ", np.round(loss_each, 0))

# 画像を可視化
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imges[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(imges_reconstruct[i][0].cpu().detach().numpy(), 'gray')
# Out:
# total loss:  [153. 213. 274. 231. 199.]
